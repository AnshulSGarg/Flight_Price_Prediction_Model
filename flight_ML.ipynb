# %% [markdown]
# # Model Flow

# %%
# Import Data
# Understanding Data
# EDA
# Outliers
# Feature Engineering
# Feature Selection
# ML Models
# Model Selection

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import datetime as datetime
import seaborn as sns
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
# import warnings
# warnings.filterwarnings('ignore', category=pd.core.common.SettingWithCopyWarning)
# pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
# df1 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03092024_1.csv')
# df1.head(2)

# df2 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03092024.csv')
# df2.head(2)

# df = pd.concat([df1,df2])
# df.shape

# df3 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03082024_2.csv')
# df3['round_trip_duration'] = 0
# df = pd.concat([df,df3])
# df.shape

# df4 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03082024.csv')
# df4['round_trip_duration'] = 0
# df = pd.concat([df,df4])
# df.shape

# df5 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03072024.csv')
# df5['round_trip_duration'] = 0
# df = pd.concat([df,df5])
# df.shape

# %%
df = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03102024.csv')
print(df.shape)

df7 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03112024.csv')
df = pd.concat([df,df7])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03122024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03132024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03142024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03152024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03162024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03172024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03182024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03192024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03202024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03222024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03232024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03242024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03252024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03262024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03272024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03282024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03292024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_03302024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_04012024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_04022024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_04032024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_04042024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_04052024.csv')
df = pd.concat([df,df8])
print(df.shape)

df8 = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\one_way_04062024.csv')
df = pd.concat([df,df8])
print(df.shape)

df.to_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\main_flight_data_1.csv')
# Out:
# (5136, 16)
# (10335, 16)
# (15496, 16)
# (20609, 16)
# (25694, 16)
# (30823, 16)
# (36015, 16)
# (41256, 16)
# (46529, 16)
# (51674, 16)
# (56762, 16)
# (61875, 16)
# (67076, 16)
# (72266, 16)
# (77472, 16)
# (82663, 16)
# (87963, 16)
# (93369, 16)
# (98705, 16)
# (103964, 16)
# (109129, 16)
# (114527, 16)
# (119890, 16)
# (125096, 16)
# (130215, 16)
# (135295, 16)

# %%
source_df = pd.read_csv(r'C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\main_flight_data_1.csv')
source_df.shape
# Out:
# (135295, 17)

# %%
source_df = source_df.reset_index()

# %%
source_df.columns
# Out:
# Index(['index', 'Unnamed: 0.1', 'Unnamed: 0', 'Report_Run_Time', 'carrier',
#        'from_loc', 'to_loc', 'stop', 'price', 'from_timestamp', 'to_timestamp',
#        'from_date', 'to_date', 'carbon_emission', 'overhead_bin', 'layover',
#        'details', 'round_trip_duration'],
#       dtype='object')

# %%
df = source_df[['Report_Run_Time', 'carrier', 'from_loc',
       'to_loc', 'stop', 'price', 'from_timestamp', 'to_timestamp',
       'from_date', 'to_date', 'carbon_emission', 'overhead_bin', 'layover',
       'details', 'round_trip_duration']]

# %%
df.head(2)
# Out:
#   Report_Run_Time carrier from_loc to_loc     stop  price from_timestamp  \
# 0      2024-03-10  Spirit      EWR    LAX  Nonstop  211.0        6:47 AM
# 1      2024-03-10  Alaska      EWR    LAX  Nonstop  297.0        7:30 AM
#
#   to_timestamp from_date to_date  \
# 0     10:15 AM    Mar 28  Mar 28
# 1     10:48 AM    Mar 28  Mar 28
#
#                                      carbon_emission  \
# 0  Carbon emissions estimate: 293 kilograms. -18%...
# 1  Carbon emissions estimate: 272 kilograms. -24%...
#
#                                         overhead_bin layover  \
# 0  This price for this flight doesn't include ove...     NaN
# 1                                               $297     NaN
#
#                                              details  round_trip_duration
# 0  From 211 US dollars round trip total.This pric...                   89
# 1  From 297 US dollars round trip total. Nonstop ...                   89

# %% [markdown]
# # Understanding Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135295 entries, 0 to 135294
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Report_Run_Time      135295 non-null  object
#  1   carrier              135295 non-null  object
#  2   from_loc             135295 non-null  object
#  3   to_loc               135295 non-null  object
#  4   stop                 135295 non-null  object
#  5   price                135290 non-null  float64
#  6   from_timestamp       135295 non-null  object
#  7   to_timestamp         135295 non-null  object
#  8   from_date            135295 non-null  object
#  9   to_date              135295 non-null  object
#  10  carbon_emission      135295 non-null  object
#  11  overhead_bin         135295 non-null  object
#  12  layover              18386 non-null   object
#  13  details              135295 non-null  object
#  14  round_trip_duration  135295 non-null  int64
# dtypes: float64(1), int64(1), object(13)
# memory usage: 15.5+ MB

# %%
df.isnull().sum()
# Out:
# Report_Run_Time             0
# carrier                     0
# from_loc                    0
# to_loc                      0
# stop                        0
# price                       5
# from_timestamp              0
# to_timestamp                0
# from_date                   0
# to_date                     0
# carbon_emission             0
# overhead_bin                0
# layover                116909
# details                     0
# round_trip_duration         0
# dtype: int64

# %%
### Observations
#### There is very few record where price is null

# %%
df[df['price'].isnull()]
# Out:
#        Report_Run_Time    carrier from_loc to_loc    stop  price  \
# 58894       2024-03-22  Southwest      LAX    LGA  1 stop    NaN
# 68839       2024-03-24  Southwest      LAX    LGA  1 stop    NaN
# 74219       2024-03-25  Southwest      LAX    LGA  1 stop    NaN
# 79315       2024-03-26  Southwest      LAX    LGA  1 stop    NaN
# 127312      2024-04-05  Southwest      LAX    LGA  1 stop    NaN
#
#        from_timestamp to_timestamp from_date to_date  \
# 58894         1:25 PM     11:15 PM     Jun 7   Jun 7
# 68839         9:40 AM      7:25 PM    Mar 28  Mar 28
# 74219         8:15 AM      5:55 PM    May 11  May 11
# 79315         6:35 AM      4:25 PM    Jun 23  Jun 23
# 127312        8:15 AM      5:55 PM     May 4   May 4
#
#                                           carbon_emission       overhead_bin  \
# 58894   Carbon emissions estimate: 272 kilograms. -23%...  Price unavailable
# 68839   Carbon emissions estimate: 320 kilograms. -10%...  Price unavailable
# 74219   Carbon emissions estimate: 338 kilograms. Aver...  Price unavailable
# 79315   Carbon emissions estimate: 287 kilograms. -18%...  Price unavailable
# 127312  Carbon emissions estimate: 338 kilograms. Aver...  Price unavailable
#
#                                                   layover  \
# 58894   Layover (1 of 1) is a 45 min layover at Chicag...
# 68839   Layover (1 of 1) is a 50 min layover at Denver...
# 74219   Layover (1 of 1) is a 40 min layover at Kansas...
# 79315   Layover (1 of 1) is a 50 min layover at St. Lo...
# 127312  Layover (1 of 1) is a 40 min layover at Kansas...
#
#                                                   details  round_trip_duration
# 58894   Total price is unavailable. 1 stop flight with...                   21
# 68839   Total price is unavailable. 1 stop flight with...                   56
# 74219   Total price is unavailable. 1 stop flight with...                   16
# 79315   Total price is unavailable. 1 stop flight with...                   22
# 127312  Total price is unavailable. 1 stop flight with...                   70

# %% [markdown]
# ### Observation
# - There is 1 record where price is null

# %%
df = df[~df['price'].isnull()]

# %%
df.isnull().sum()
# Out:
# Report_Run_Time             0
# carrier                     0
# from_loc                    0
# to_loc                      0
# stop                        0
# price                       0
# from_timestamp              0
# to_timestamp                0
# from_date                   0
# to_date                     0
# carbon_emission             0
# overhead_bin                0
# layover                116909
# details                     0
# round_trip_duration         0
# dtype: int64

# %%
df.describe().T
# Out:
#                         count        mean         std   min    25%    50%  \
# price                135290.0  354.704827  174.603820  46.0  229.0  329.0
# round_trip_duration  135290.0   24.938303   29.762116   0.0    0.0    9.0
#
#                        75%     max
# price                452.0  4074.0
# round_trip_duration   49.0    90.0

# %%
df[df.duplicated()].shape
# Out:
# (43, 15)

# %%
df.columns
# Out:
# Index(['Report_Run_Time', 'carrier', 'from_loc', 'to_loc', 'stop', 'price',
#        'from_timestamp', 'to_timestamp', 'from_date', 'to_date',
#        'carbon_emission', 'overhead_bin', 'layover', 'details',
#        'round_trip_duration'],
#       dtype='object')

# %%
df[(df['carrier']=='Spirit') & (df['stop']=='2 stops') & (df['price']== 236) & (df['from_date']== 'Mar 15')]['layover'].unique()
# Out:
# array(['Layover (1 of 2) is a 39 min layover at Detroit Metropolitan Wayne County Airport in Detroit. Layover (2 of 2) is a 7 hr 48 min overnight layover at Harry Reid International Airport in Las Vegas.',
#        'Layover (1 of 2) is a 1 hr 35 min layover at Detroit Metropolitan Wayne County Airport in Detroit. Layover (2 of 2) is a 6 hr 50 min overnight layover at Harry Reid International Airport in Las Vegas.'],
#       dtype=object)

# %%
df = df.drop_duplicates(keep='first')

# %% [markdown]
# ### Observation
#
# - Dropping duplicates rows
# - Looks like there are records that are duplicate except distinct layover
# - If different layover options are ignored later in the analysis then more duplicate rows will need to be removed

# %%
df.shape
# Out:
# (135247, 15)

# %% [markdown]
# # EDA

# %% [markdown]
# ## EDA - Univariate Analysis

# %%
pd.DataFrame(df.columns)
# Out:
#                       0
# 0       Report_Run_Time
# 1               carrier
# 2              from_loc
# 3                to_loc
# 4                  stop
# 5                 price
# 6        from_timestamp
# 7          to_timestamp
# 8             from_date
# 9               to_date
# 10      carbon_emission
# 11         overhead_bin
# 12              layover
# 13              details
# 14  round_trip_duration

# %% [markdown]
# ## 0.Report Run Time

# %%
df['Report_Run_Time'] = pd.to_datetime(df['Report_Run_Time'])
df['Report_Run_Time'] = df['Report_Run_Time'].dt.date
df['Report_Run_Time'].value_counts().sort_index()
# Out:
# Report_Run_Time
# 2024-03-10    5136
# 2024-03-11    5156
# 2024-03-12    5161
# 2024-03-13    5113
# 2024-03-14    5085
# 2024-03-15    5129
# 2024-03-16    5192
# 2024-03-17    5241
# 2024-03-18    5273
# 2024-03-19    5145
# 2024-03-21    5088
# 2024-03-22    5112
# 2024-03-23    5201
# 2024-03-24    5189
# 2024-03-25    5205
# 2024-03-26    5190
# 2024-03-27    5300
# 2024-03-28    5406
# 2024-03-29    5336
# 2024-03-30    5259
# 2024-04-01    5165
# 2024-04-02    5398
# 2024-04-03    5363
# 2024-04-04    5206
# 2024-04-05    5118
# 2024-04-06    5080
# Name: count, dtype: int64

# %%
df['Report_Run_Time'].value_counts().sort_index().plot(kind='bar',)
# Out:
# <Axes: xlabel='Report_Run_Time'>

# %% [markdown]
# ## 1.carrier column

# %%
df.carrier.value_counts()
# Out:
# carrier
# JetBlue                                                                                                                                                34795
# United                                                                                                                                                 27310
# American                                                                                                                                               25857
# Delta                                                                                                                                                  24609
# Spirit                                                                                                                                                  9187
# Alaska                                                                                                                                                  7930
# Separate tickets booked togetherThis trip includes tickets from multiple airlines. Missed connections may be protected by Kiwi.com. Learn more          3560
# Frontier                                                                                                                                                1331
# Separate tickets booked togetherThis trip includes tickets from multiple airlines. Missed connections may be protected by Dohop Connect. Learn more      341
# Sun Country Airlines                                                                                                                                     254
# Separate tickets booked togetherThis trip includes tickets from multiple airlines. Missed connections may be protected by Gotogate. Learn more            73
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
#
# - There are trips which include traveling through multiple airlines.
# - This usually involves purchasing ticket from 3rd party agencies.
# - As there are good enough options available from 1st party carriers, these data points can be excluded from the model
# - However, when analyzed if there are reason to keep these data points, it looks like these carriers provide better price point to customers.
# - As, one of the objective of this model is to share flight options with cheaper options, I will keep these data point and bucket them as third party

# %%
third_party_df = df[df['carrier'].str.contains('Separate tickets')]
third_party_df.head(2)
# Out:
#   Report_Run_Time                                            carrier from_loc  \
# 5      2024-03-10  Separate tickets booked togetherThis trip incl...      EWR
# 6      2024-03-10  Separate tickets booked togetherThis trip incl...      LGA
#
#   to_loc     stop  price from_timestamp to_timestamp from_date to_date  \
# 5    LAX   1 stop  270.0        7:47 AM     12:54 PM    Mar 28  Mar 28
# 6    LAX  2 stops  285.0       10:50 PM     11:03 AM    Mar 28  Mar 28
#
#                                      carbon_emission  \
# 5  Carbon emissions estimate: 295 kilograms. -18%...
# 6  Carbon emissions estimate: 317 kilograms. -12%...
#
#                                         overhead_bin  \
# 5  This price for this flight doesn't include ove...
# 6  This price for this flight doesn't include ove...
#
#                                              layover  \
# 5  Layover (1 of 1) is a 1 hr 3 min layover at Ha...
# 6  Layover (1 of 2) is a 4 hr 23 min overnight la...
#
#                                              details  round_trip_duration
# 5  From 270 US dollars round trip total.This pric...                   89
# 6  From 285 US dollars round trip total.This pric...                   89

# %%
df.loc[df['carrier'].str.contains('Separate tickets'), 'carrier'] = 'Third Party'

# %%
df.carrier.value_counts()
# Out:
# carrier
# JetBlue                 34795
# United                  27310
# American                25857
# Delta                   24609
# Spirit                   9187
# Alaska                   7930
# Third Party              3974
# Frontier                 1331
# Sun Country Airlines      254
# Name: count, dtype: int64

# %%
df.carrier.value_counts()
df['carrier'].value_counts().plot(kind='bar',)
# Out:
# <Axes: xlabel='carrier'>

# %% [markdown]
# ### Observation
# - JetBlue seems to have most number of trip options (including one way and round trip)
# - United and American and Delta seems to be 2nd spot
# - Spirit, Alaska seems to be 3rd most number of trip options and  rest of the carriers have less than thousand

# %% [markdown]
# ## 2.From Airport

# %%
df.from_loc.value_counts()
# Out:
# from_loc
# LAX    66686
# JFK    37363
# EWR    26489
# LGA     4709
# Name: count, dtype: int64

# %% [markdown]
# ## 3.To Airport

# %%
df.to_loc.value_counts()
# Out:
# to_loc
# LAX    68561
# JFK    34220
# EWR    26376
# LGA     6090
# Name: count, dtype: int64

# %% [markdown]
# ### 3.1 Airport Route(New Column)

# %%
df['Airport_Route'] = df['from_loc'] + " - " + df['to_loc']

# %%
df.from_loc.unique()
# Out:
# array(['EWR', 'LGA', 'JFK', 'LAX'], dtype=object)

# %%
df.to_loc.unique()
# Out:
# array(['LAX', 'EWR', 'LGA', 'JFK'], dtype=object)

# %% [markdown]
# ### 3.2 City Route (New Column)

# %%
df.loc[df.from_loc == 'LAX','From_City'] = 'Los Angeles'
df.loc[df.from_loc == 'LGA','From_City'] = 'New York City'
df.loc[df.from_loc == 'EWR','From_City'] = 'New York City'
df.loc[df.from_loc == 'JFK','From_City'] = 'New York City'

df.loc[df.to_loc == 'LAX','To_City'] = 'Los Angeles'
df.loc[df.to_loc == 'LGA','To_City'] = 'New York City'
df.loc[df.to_loc == 'EWR','To_City'] = 'New York City'
df.loc[df.to_loc == 'JFK','To_City'] = 'New York City'

# %%
df['City_Route'] = df['From_City'] + " - " + df['To_City']

# %%
df.City_Route.value_counts()
# Out:
# City_Route
# New York City - Los Angeles    68561
# Los Angeles - New York City    66686
# Name: count, dtype: int64

# %% [markdown]
# ## 4.Stop

# %%
df.stop.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='stop'>

# %% [markdown]
# ### Observation
#
# - More flight options are non stop as compared to around other flight options

# %% [markdown]
# ## 5.Price

# %% [markdown]
# ### Price

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot distribution plot on the first subplot
sns.histplot(df['price'], kde=True, bins=50, ax=axes[0])
axes[0].set_title('Distribution Plot')

# Plot box plot on the second subplot
sns.boxplot(df['price'], ax=axes[1], color='green')
axes[1].set_title('Box Plot')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1,2,1)
sns.histplot(np.log(df['price']), kde=True, bins=50)

plt.subplot(1,2,2)
sns.boxplot(np.log(df['price']), color='green')

plt.tight_layout()
plt.show()

# %%
skewness = np.log(df['price']).skew()
kurtosis = np.log(df['price']).kurt()

print(skewness,kurtosis)
# Out:
# -0.2457568441801861 -0.16868762747139732

# %%
df.price.mean()
# Out:
# 354.7354322092172

# %%
df.price.median()
# Out:
# 329.0

# %%
df.price.mode()
# Out:
# 0    229.0
# Name: price, dtype: float64

# %% [markdown]
# ### Observation
# - Price distribution seems to be right tail. Using log transformation makes the distribution even tail.

# %% [markdown]
# ## 6.From timestamp

# %%
df['from_timestamp'] = pd.to_datetime(df['from_timestamp']).dt.time
df['from_timestamp']
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\2401876065.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['from_timestamp'] = pd.to_datetime(df['from_timestamp']).dt.time
# 0         06:47:00
# 1         07:30:00
# 2         05:15:00
# 3         12:00:00
# 4         16:29:00
#             ...
# 135290    10:20:00
# 135291    11:20:00
# 135292    06:00:00
# 135293    09:20:00
# 135294    16:00:00
# Name: from_timestamp, Length: 135247, dtype: object

# %%
df['from_hour'] = df['from_timestamp'].apply(lambda x:x.hour)

# %%
df['from_hour'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='from_hour'>

# %%
df.loc[(df['from_hour'] >= 0) & (df['from_hour'] < 3),'from_hour_segment'] = '1. 12 AM - 3 AM'
df.loc[(df['from_hour'] >= 3) & (df['from_hour'] < 6),'from_hour_segment'] = '2. 3 AM - 6 AM'
df.loc[(df['from_hour'] >= 6) & (df['from_hour'] < 9),'from_hour_segment'] = '3. 6 AM - 9 AM'
df.loc[(df['from_hour'] >= 9) & (df['from_hour'] < 12),'from_hour_segment'] = '4. 9 AM - 12 PM'
df.loc[(df['from_hour'] >= 12) & (df['from_hour'] < 15),'from_hour_segment'] = '5. 12 PM - 3 PM'
df.loc[(df['from_hour'] >= 15) & (df['from_hour'] < 18),'from_hour_segment'] = '6. 3 PM - 6 PM'
df.loc[(df['from_hour'] >= 18) & (df['from_hour'] < 21),'from_hour_segment'] = '7. 6 PM - 9 PM'
df.loc[(df['from_hour'] >= 21) & (df['from_hour'] < 24),'from_hour_segment'] = '8. 9 PM - 12 AM'

# %%
df['from_hour_segment'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='from_hour_segment'>

# %% [markdown]
# ### Observation
# - Most of the flight options are available b/w 7 and 8 am.
# - Next most options are available b/w 6 am and 9 pm
#
#
#
#
# - If we group the flight start time then 6 am - 9 am seems to be most frequent time the carriers fly
# - 9 pm - 12 am and 9 AM - 12 PM seems to be next most frequent

# %% [markdown]
# ## 7.To timestamp

# %%
df['to_timestamp'] = pd.to_datetime(df['to_timestamp']).dt.time
df['to_timestamp']
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\730532032.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['to_timestamp'] = pd.to_datetime(df['to_timestamp']).dt.time
# 0         10:15:00
# 1         10:48:00
# 2         08:30:00
# 3         15:24:00
# 4         17:00:00
#             ...
# 135290    18:59:00
# 135291    19:49:00
# 135292    14:35:00
# 135293    18:15:00
# 135294    00:37:00
# Name: to_timestamp, Length: 135247, dtype: object

# %%
df['to_hour'] = df['to_timestamp'].apply(lambda x:x.hour)

# %%
df['to_hour'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='to_hour'>

# %%
df.loc[(df['to_hour'] >= 0) & (df['to_hour'] < 3),'to_hour_segment'] = '1. 12 AM - 3 AM'
df.loc[(df['to_hour'] >= 3) & (df['to_hour'] < 6),'to_hour_segment'] = '2. 3 AM - 6 AM'
df.loc[(df['to_hour'] >= 6) & (df['to_hour'] < 9),'to_hour_segment'] = '3. 6 AM - 9 AM'
df.loc[(df['to_hour'] >= 9) & (df['to_hour'] < 12),'to_hour_segment'] = '4. 9 AM - 12 PM'
df.loc[(df['to_hour'] >= 12) & (df['to_hour'] < 15),'to_hour_segment'] = '5. 12 PM - 3 PM'
df.loc[(df['to_hour'] >= 15) & (df['to_hour'] < 18),'to_hour_segment'] = '6. 3 PM - 6 PM'
df.loc[(df['to_hour'] >= 18) & (df['to_hour'] < 21),'to_hour_segment'] = '7. 6 PM - 9 PM'
df.loc[(df['to_hour'] >= 21) & (df['to_hour'] < 24),'to_hour_segment'] = '8. 9 PM - 12 AM'

# %%
df['to_hour_segment'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='to_hour_segment'>

# %% [markdown]
# ### Observation
# - Most of the flight options are available b/w 7 and 9 pm.
#
# - There are more flights that reach destination after 6 pm

# %%
df[df['layover']=='Layover (1 of 2) is a 1 hr 9 min layover at Harry Reid International Airport in Las Vegas. Layover (2 of 2) is a 12 hr 54 min layover at Phoenix Sky Harbor International Airport in Phoenix.']['details'].values
# Out:
# array(['From 165 US dollars.This price does not include overhead bin access. 2 stops flight with Spirit. Leaves Los Angeles International Airport at 6:45\u202fAM on Monday, April 1 and arrives at Newark Liberty International Airport at 6:47\u202fAM on Tuesday, April 2. Total duration 21 hr 2 min. Layover (1 of 2) is a 1 hr 9 min layover at Harry Reid International Airport in Las Vegas. Layover (2 of 2) is a 12 hr 54 min layover at Phoenix Sky Harbor International Airport in Phoenix. Separate tickets booked together. This trip includes tickets from multiple airlines. Missed connections may be protected by Kiwi.com. Select flight',
#        'From 296 US dollars round trip total.This price does not include overhead bin access. 2 stops flight with Spirit. Leaves Los Angeles International Airport at 6:45\u202fAM on Tuesday, April 2 and arrives at Newark Liberty International Airport at 6:47\u202fAM on Wednesday, April 3. Total duration 21 hr 2 min. Layover (1 of 2) is a 1 hr 9 min layover at Harry Reid International Airport in Las Vegas. Layover (2 of 2) is a 12 hr 54 min layover at Phoenix Sky Harbor International Airport in Phoenix. Separate tickets booked together. This trip includes tickets from multiple airlines. Missed connections may be protected by Kiwi.com. Select flight'],
#       dtype=object)

# %% [markdown]
# ## 8.From date

# %%
df['from_date'] = pd.to_datetime(df['from_date'] + ' 2024', format='%b %d %Y')
df['to_date'] = pd.to_datetime(df['to_date'] + ' 2024', format='%b %d %Y')

# %%
plt.figure(figsize=(16, 8))
(df['from_date'].dt.date).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='from_date'>

# %% [markdown]
# ### Holiday (New Column)

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
cal = USFederalHolidayCalendar()
holidays = cal.holidays(start='2024-01-01', end='2024-12-31').to_pydatetime()
holiday_df = pd.DataFrame(holidays, columns=['Holiday'])
holiday_df
# Out:
#       Holiday
# 0  2024-01-01
# 1  2024-01-15
# 2  2024-02-19
# 3  2024-05-27
# 4  2024-06-19
# 5  2024-07-04
# 6  2024-09-02
# 7  2024-10-14
# 8  2024-11-11
# 9  2024-11-28
# 10 2024-12-25

# %%
df.loc[df['from_date'].isin(holiday_df['Holiday']),'Holiday'] = 'Holiday'
df.loc[~df['from_date'].isin(holiday_df['Holiday']),'Holiday'] = 'Not_Holiday'

# %%
df['Holiday'].value_counts()
# Out:
# Holiday
# Not_Holiday    132619
# Holiday          2628
# Name: count, dtype: int64

# %% [markdown]
# ## 9.To Date

# %%
plt.figure(figsize=(16, 8))
(df['to_date'].dt.date).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='to_date'>

# %% [markdown]
# ### Observation
# - Scraping seems to be collecting good amount of data from different days which can help in unbiased analysis b/w flight journey date and price.

# %% [markdown]
# ### 9.1 Days to Fly (New Column)

# %%
df['Days_to_Fly'] = df['from_date'] - pd.to_datetime(df['Report_Run_Time'])
df['Days_to_Fly'] = df['Days_to_Fly'].dt.days
df.head(2)
# Out:
#   Report_Run_Time carrier from_loc to_loc     stop  price from_timestamp  \
# 0      2024-03-10  Spirit      EWR    LAX  Nonstop  211.0       06:47:00
# 1      2024-03-10  Alaska      EWR    LAX  Nonstop  297.0       07:30:00
#
#   to_timestamp  from_date    to_date  ... Airport_Route      From_City  \
# 0     10:15:00 2024-03-28 2024-03-28  ...     EWR - LAX  New York City
# 1     10:48:00 2024-03-28 2024-03-28  ...     EWR - LAX  New York City
#
#        To_City                   City_Route  from_hour from_hour_segment  \
# 0  Los Angeles  New York City - Los Angeles          6    3. 6 AM - 9 AM
# 1  Los Angeles  New York City - Los Angeles          7    3. 6 AM - 9 AM
#
#   to_hour  to_hour_segment      Holiday  Days_to_Fly
# 0      10  4. 9 AM - 12 PM  Not_Holiday           18
# 1      10  4. 9 AM - 12 PM  Not_Holiday           18
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Observation
#
# - Time to fly from the booking data is b/w 1 and 90 and seems to be random

# %% [markdown]
# ### 9.2Flight Duration (New Column)

# %%
df['from_timestamp_1'] = pd.to_datetime(df['from_date']) + pd.to_timedelta(df['from_timestamp'].astype(str))
df['to_timestamp_1'] = pd.to_datetime(df['to_date']) + pd.to_timedelta(df['to_timestamp'].astype(str))
df.head(2)
# Out:
#   Report_Run_Time carrier from_loc to_loc     stop  price from_timestamp  \
# 0      2024-03-10  Spirit      EWR    LAX  Nonstop  211.0       06:47:00
# 1      2024-03-10  Alaska      EWR    LAX  Nonstop  297.0       07:30:00
#
#   to_timestamp  from_date    to_date  ...      To_City  \
# 0     10:15:00 2024-03-28 2024-03-28  ...  Los Angeles
# 1     10:48:00 2024-03-28 2024-03-28  ...  Los Angeles
#
#                     City_Route from_hour from_hour_segment  to_hour  \
# 0  New York City - Los Angeles         6    3. 6 AM - 9 AM       10
# 1  New York City - Los Angeles         7    3. 6 AM - 9 AM       10
#
#    to_hour_segment      Holiday Days_to_Fly    from_timestamp_1  \
# 0  4. 9 AM - 12 PM  Not_Holiday          18 2024-03-28 06:47:00
# 1  4. 9 AM - 12 PM  Not_Holiday          18 2024-03-28 07:30:00
#
#        to_timestamp_1
# 0 2024-03-28 10:15:00
# 1 2024-03-28 10:48:00
#
# [2 rows x 27 columns]

# %%
df['flight_duration'] = df['to_timestamp_1'] - df['from_timestamp_1']
df.head()
# Out:
#   Report_Run_Time  carrier from_loc to_loc     stop  price from_timestamp  \
# 0      2024-03-10   Spirit      EWR    LAX  Nonstop  211.0       06:47:00
# 1      2024-03-10   Alaska      EWR    LAX  Nonstop  297.0       07:30:00
# 2      2024-03-10  JetBlue      EWR    LAX  Nonstop  298.0       05:15:00
# 3      2024-03-10   United      EWR    LAX  Nonstop  302.0       12:00:00
# 4      2024-03-10   Spirit      LGA    LAX   1 stop  269.0       16:29:00
#
#   to_timestamp  from_date    to_date  ...                   City_Route  \
# 0     10:15:00 2024-03-28 2024-03-28  ...  New York City - Los Angeles
# 1     10:48:00 2024-03-28 2024-03-28  ...  New York City - Los Angeles
# 2     08:30:00 2024-03-28 2024-03-28  ...  New York City - Los Angeles
# 3     15:24:00 2024-03-28 2024-03-28  ...  New York City - Los Angeles
# 4     17:00:00 2024-03-28 2024-03-28  ...  New York City - Los Angeles
#
#   from_hour from_hour_segment to_hour  to_hour_segment      Holiday  \
# 0         6    3. 6 AM - 9 AM      10  4. 9 AM - 12 PM  Not_Holiday
# 1         7    3. 6 AM - 9 AM      10  4. 9 AM - 12 PM  Not_Holiday
# 2         5    2. 3 AM - 6 AM       8   3. 6 AM - 9 AM  Not_Holiday
# 3        12   5. 12 PM - 3 PM      15   6. 3 PM - 6 PM  Not_Holiday
# 4        16    6. 3 PM - 6 PM      17   6. 3 PM - 6 PM  Not_Holiday
#
#   Days_to_Fly    from_timestamp_1      to_timestamp_1  flight_duration
# 0          18 2024-03-28 06:47:00 2024-03-28 10:15:00  0 days 03:28:00
# 1          18 2024-03-28 07:30:00 2024-03-28 10:48:00  0 days 03:18:00
# 2          18 2024-03-28 05:15:00 2024-03-28 08:30:00  0 days 03:15:00
# 3          18 2024-03-28 12:00:00 2024-03-28 15:24:00  0 days 03:24:00
# 4          18 2024-03-28 16:29:00 2024-03-28 17:00:00  0 days 00:31:00
#
# [5 rows x 28 columns]

# %%
df.loc[df['flight_duration'].dt.total_seconds() < 0, 'to_timestamp_1'] += pd.to_timedelta('1 day')

# %%
df['flight_duration'] = df['to_timestamp_1'] - df['from_timestamp_1']

# %%
df[df['flight_duration'].dt.total_seconds() < 0]
# Out:
# Empty DataFrame
# Columns: [Report_Run_Time, carrier, from_loc, to_loc, stop, price, from_timestamp, to_timestamp, from_date, to_date, carbon_emission, overhead_bin, layover, details, round_trip_duration, Airport_Route, From_City, To_City, City_Route, from_hour, from_hour_segment, to_hour, to_hour_segment, Holiday, Days_to_Fly, from_timestamp_1, to_timestamp_1, flight_duration]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.details.values
# Out:
# array(['From 211 US dollars round trip total.This price does not include overhead bin access. Nonstop flight with Spirit. Leaves Newark Liberty International Airport at 6:47\u202fAM on Thursday, March 28 and arrives at Los Angeles International Airport at 10:15\u202fAM on Thursday, March 28. Total duration 6 hr 28 min.  Select flight',
#        'From 297 US dollars round trip total. Nonstop flight with Alaska. Leaves Newark Liberty International Airport at 7:30\u202fAM on Thursday, March 28 and arrives at Los Angeles International Airport at 10:48\u202fAM on Thursday, March 28. Total duration 6 hr 18 min.  Select flight',
#        'From 298 US dollars round trip total.This price does not include overhead bin access. Nonstop flight with JetBlue. Leaves Newark Liberty International Airport at 5:15\u202fAM on Thursday, March 28 and arrives at Los Angeles International Airport at 8:30\u202fAM on Thursday, March 28. Total duration 6 hr 15 min.  Select flight',
#        ...,
#        'From 274 US dollars. Nonstop flight with Delta. Leaves Los Angeles International Airport at 6:00\u202fAM on Thursday, July 4 and arrives at John F. Kennedy International Airport at 2:35\u202fPM on Thursday, July 4. Total duration 5 hr 35 min.  Select flight',
#        'From 274 US dollars. Nonstop flight with Delta. Leaves Los Angeles International Airport at 9:20\u202fAM on Thursday, July 4 and arrives at John F. Kennedy International Airport at 6:15\u202fPM on Thursday, July 4. Total duration 5 hr 55 min.  Select flight',
#        'From 274 US dollars. Nonstop flight with Delta. Leaves Los Angeles International Airport at 4:00\u202fPM on Thursday, July 4 and arrives at John F. Kennedy International Airport at 12:37\u202fAM on Friday, July 5. Total duration 5 hr 37 min.  Select flight'],
#       dtype=object)

# %%
df[['Hours', 'Minutes']] = df['details'].str.extract(r'Total duration (\d+) hr(?: (\d+) min)?')

# Fill NaN values in 'Minutes' column with 0, since some rows might not have minutes information
df['Minutes'] = df['Minutes'].fillna(0).astype(int)

# Display DataFrame

# %%
df['Hours'] = pd.to_numeric(df['Hours'])
df['Minutes'] = pd.to_numeric(df['Minutes'])
df
# Out:
#        Report_Run_Time  carrier from_loc to_loc     stop  price  \
# 0           2024-03-10   Spirit      EWR    LAX  Nonstop  211.0
# 1           2024-03-10   Alaska      EWR    LAX  Nonstop  297.0
# 2           2024-03-10  JetBlue      EWR    LAX  Nonstop  298.0
# 3           2024-03-10   United      EWR    LAX  Nonstop  302.0
# 4           2024-03-10   Spirit      LGA    LAX   1 stop  269.0
# ...                ...      ...      ...    ...      ...    ...
# 135290      2024-04-06   Alaska      LAX    EWR  Nonstop  259.0
# 135291      2024-04-06  JetBlue      LAX    EWR  Nonstop  259.0
# 135292      2024-04-06    Delta      LAX    JFK  Nonstop  274.0
# 135293      2024-04-06    Delta      LAX    JFK  Nonstop  274.0
# 135294      2024-04-06    Delta      LAX    JFK  Nonstop  274.0
#
#        from_timestamp to_timestamp  from_date    to_date  ...  \
# 0            06:47:00     10:15:00 2024-03-28 2024-03-28  ...
# 1            07:30:00     10:48:00 2024-03-28 2024-03-28  ...
# 2            05:15:00     08:30:00 2024-03-28 2024-03-28  ...
# 3            12:00:00     15:24:00 2024-03-28 2024-03-28  ...
# 4            16:29:00     17:00:00 2024-03-28 2024-03-28  ...
# ...               ...          ...        ...        ...  ...
# 135290       10:20:00     18:59:00 2024-07-04 2024-07-05  ...
# 135291       11:20:00     19:49:00 2024-07-04 2024-07-05  ...
# 135292       06:00:00     14:35:00 2024-07-04 2024-07-05  ...
# 135293       09:20:00     18:15:00 2024-07-04 2024-07-05  ...
# 135294       16:00:00     00:37:00 2024-07-04 2024-07-05  ...
#
#        from_hour_segment to_hour  to_hour_segment      Holiday  Days_to_Fly  \
# 0         3. 6 AM - 9 AM      10  4. 9 AM - 12 PM  Not_Holiday           18
# 1         3. 6 AM - 9 AM      10  4. 9 AM - 12 PM  Not_Holiday           18
# 2         2. 3 AM - 6 AM       8   3. 6 AM - 9 AM  Not_Holiday           18
# 3        5. 12 PM - 3 PM      15   6. 3 PM - 6 PM  Not_Holiday           18
# 4         6. 3 PM - 6 PM      17   6. 3 PM - 6 PM  Not_Holiday           18
# ...                  ...     ...              ...          ...          ...
# 135290   4. 9 AM - 12 PM      18   7. 6 PM - 9 PM      Holiday           89
# 135291   4. 9 AM - 12 PM      19   7. 6 PM - 9 PM      Holiday           89
# 135292    3. 6 AM - 9 AM      14  5. 12 PM - 3 PM      Holiday           89
# 135293   4. 9 AM - 12 PM      18   7. 6 PM - 9 PM      Holiday           89
# 135294    6. 3 PM - 6 PM       0  1. 12 AM - 3 AM      Holiday           89
#
#           from_timestamp_1      to_timestamp_1 flight_duration Hours  Minutes
# 0      2024-03-28 06:47:00 2024-03-28 10:15:00 0 days 03:28:00   6.0       28
# 1      2024-03-28 07:30:00 2024-03-28 10:48:00 0 days 03:18:00   6.0       18
# 2      2024-03-28 05:15:00 2024-03-28 08:30:00 0 days 03:15:00   6.0       15
# 3      2024-03-28 12:00:00 2024-03-28 15:24:00 0 days 03:24:00   6.0       24
# 4      2024-03-28 16:29:00 2024-03-28 17:00:00 0 days 00:31:00  27.0       31
# ...                    ...                 ...             ...   ...      ...
# 135290 2024-07-04 10:20:00 2024-07-05 18:59:00 1 days 08:39:00   5.0       39
# 135291 2024-07-04 11:20:00 2024-07-05 19:49:00 1 days 08:29:00   5.0       29
# 135292 2024-07-04 06:00:00 2024-07-05 14:35:00 1 days 08:35:00   5.0       35
# 135293 2024-07-04 09:20:00 2024-07-05 18:15:00 1 days 08:55:00   5.0       55
# 135294 2024-07-04 16:00:00 2024-07-05 00:37:00 0 days 08:37:00   5.0       37
#
# [135247 rows x 30 columns]

# %% [markdown]
# ### Flight Time

# %%
df['Flight_Time'] = df['Hours'] + round(df['Minutes']/60,1)
df
# Out:
#        Report_Run_Time  carrier from_loc to_loc     stop  price  \
# 0           2024-03-10   Spirit      EWR    LAX  Nonstop  211.0
# 1           2024-03-10   Alaska      EWR    LAX  Nonstop  297.0
# 2           2024-03-10  JetBlue      EWR    LAX  Nonstop  298.0
# 3           2024-03-10   United      EWR    LAX  Nonstop  302.0
# 4           2024-03-10   Spirit      LGA    LAX   1 stop  269.0
# ...                ...      ...      ...    ...      ...    ...
# 135290      2024-04-06   Alaska      LAX    EWR  Nonstop  259.0
# 135291      2024-04-06  JetBlue      LAX    EWR  Nonstop  259.0
# 135292      2024-04-06    Delta      LAX    JFK  Nonstop  274.0
# 135293      2024-04-06    Delta      LAX    JFK  Nonstop  274.0
# 135294      2024-04-06    Delta      LAX    JFK  Nonstop  274.0
#
#        from_timestamp to_timestamp  from_date    to_date  ... to_hour  \
# 0            06:47:00     10:15:00 2024-03-28 2024-03-28  ...      10
# 1            07:30:00     10:48:00 2024-03-28 2024-03-28  ...      10
# 2            05:15:00     08:30:00 2024-03-28 2024-03-28  ...       8
# 3            12:00:00     15:24:00 2024-03-28 2024-03-28  ...      15
# 4            16:29:00     17:00:00 2024-03-28 2024-03-28  ...      17
# ...               ...          ...        ...        ...  ...     ...
# 135290       10:20:00     18:59:00 2024-07-04 2024-07-05  ...      18
# 135291       11:20:00     19:49:00 2024-07-04 2024-07-05  ...      19
# 135292       06:00:00     14:35:00 2024-07-04 2024-07-05  ...      14
# 135293       09:20:00     18:15:00 2024-07-04 2024-07-05  ...      18
# 135294       16:00:00     00:37:00 2024-07-04 2024-07-05  ...       0
#
#         to_hour_segment      Holiday Days_to_Fly    from_timestamp_1  \
# 0       4. 9 AM - 12 PM  Not_Holiday          18 2024-03-28 06:47:00
# 1       4. 9 AM - 12 PM  Not_Holiday          18 2024-03-28 07:30:00
# 2        3. 6 AM - 9 AM  Not_Holiday          18 2024-03-28 05:15:00
# 3        6. 3 PM - 6 PM  Not_Holiday          18 2024-03-28 12:00:00
# 4        6. 3 PM - 6 PM  Not_Holiday          18 2024-03-28 16:29:00
# ...                 ...          ...         ...                 ...
# 135290   7. 6 PM - 9 PM      Holiday          89 2024-07-04 10:20:00
# 135291   7. 6 PM - 9 PM      Holiday          89 2024-07-04 11:20:00
# 135292  5. 12 PM - 3 PM      Holiday          89 2024-07-04 06:00:00
# 135293   7. 6 PM - 9 PM      Holiday          89 2024-07-04 09:20:00
# 135294  1. 12 AM - 3 AM      Holiday          89 2024-07-04 16:00:00
#
#             to_timestamp_1 flight_duration Hours Minutes  Flight_Time
# 0      2024-03-28 10:15:00 0 days 03:28:00   6.0      28          6.5
# 1      2024-03-28 10:48:00 0 days 03:18:00   6.0      18          6.3
# 2      2024-03-28 08:30:00 0 days 03:15:00   6.0      15          6.2
# 3      2024-03-28 15:24:00 0 days 03:24:00   6.0      24          6.4
# 4      2024-03-28 17:00:00 0 days 00:31:00  27.0      31         27.5
# ...                    ...             ...   ...     ...          ...
# 135290 2024-07-05 18:59:00 1 days 08:39:00   5.0      39          5.6
# 135291 2024-07-05 19:49:00 1 days 08:29:00   5.0      29          5.5
# 135292 2024-07-05 14:35:00 1 days 08:35:00   5.0      35          5.6
# 135293 2024-07-05 18:15:00 1 days 08:55:00   5.0      55          5.9
# 135294 2024-07-05 00:37:00 0 days 08:37:00   5.0      37          5.6
#
# [135247 rows x 31 columns]

# %%
df['Flight_Time'].min()
# Out:
# 2.5

# %% [markdown]
# ### 9.3Fly_Weekday (New Column)

# %%
df['Fly_WeekDay'] = df['from_timestamp_1'].dt.weekday + 1

# %% [markdown]
# ### 9.4Flight Duration Value (New Column)

# %%
df['flight_duration_value'] = round(df.flight_duration.dt.seconds/3600,1)
df.head(5)
# Out:
#   Report_Run_Time  carrier from_loc to_loc     stop  price from_timestamp  \
# 0      2024-03-10   Spirit      EWR    LAX  Nonstop  211.0       06:47:00
# 1      2024-03-10   Alaska      EWR    LAX  Nonstop  297.0       07:30:00
# 2      2024-03-10  JetBlue      EWR    LAX  Nonstop  298.0       05:15:00
# 3      2024-03-10   United      EWR    LAX  Nonstop  302.0       12:00:00
# 4      2024-03-10   Spirit      LGA    LAX   1 stop  269.0       16:29:00
#
#   to_timestamp  from_date    to_date  ...      Holiday Days_to_Fly  \
# 0     10:15:00 2024-03-28 2024-03-28  ...  Not_Holiday          18
# 1     10:48:00 2024-03-28 2024-03-28  ...  Not_Holiday          18
# 2     08:30:00 2024-03-28 2024-03-28  ...  Not_Holiday          18
# 3     15:24:00 2024-03-28 2024-03-28  ...  Not_Holiday          18
# 4     17:00:00 2024-03-28 2024-03-28  ...  Not_Holiday          18
#
#      from_timestamp_1      to_timestamp_1  flight_duration Hours Minutes  \
# 0 2024-03-28 06:47:00 2024-03-28 10:15:00  0 days 03:28:00   6.0      28
# 1 2024-03-28 07:30:00 2024-03-28 10:48:00  0 days 03:18:00   6.0      18
# 2 2024-03-28 05:15:00 2024-03-28 08:30:00  0 days 03:15:00   6.0      15
# 3 2024-03-28 12:00:00 2024-03-28 15:24:00  0 days 03:24:00   6.0      24
# 4 2024-03-28 16:29:00 2024-03-28 17:00:00  0 days 00:31:00  27.0      31
#
#   Flight_Time Fly_WeekDay  flight_duration_value
# 0         6.5           4                    3.5
# 1         6.3           4                    3.3
# 2         6.2           4                    3.2
# 3         6.4           4                    3.4
# 4        27.5           4                    0.5
#
# [5 rows x 33 columns]

# %%
df.sort_values('flight_duration_value').head()
# Out:
#        Report_Run_Time      carrier from_loc to_loc     stop  price  \
# 126935      2024-04-05  Third Party      LAX    LGA  2 stops  427.0
# 65305       2024-03-23  Third Party      EWR    LAX  2 stops  150.0
# 77282       2024-03-25  Third Party      LAX    EWR  2 stops  223.0
# 56701       2024-03-21  Third Party      LAX    EWR  2 stops  194.0
# 97347       2024-03-29  Third Party      LGA    LAX  2 stops  123.0
#
#        from_timestamp to_timestamp  from_date    to_date  ...      Holiday  \
# 126935       23:15:00     23:18:00 2024-06-27 2024-06-28  ...  Not_Holiday
# 65305        22:28:00     22:31:00 2024-04-21 2024-04-21  ...  Not_Holiday
# 77282        06:45:00     06:47:00 2024-04-01 2024-04-02  ...  Not_Holiday
# 56701        06:45:00     06:47:00 2024-04-03 2024-04-03  ...  Not_Holiday
# 97347        08:37:00     08:40:00 2024-04-28 2024-04-28  ...  Not_Holiday
#
#        Days_to_Fly    from_timestamp_1      to_timestamp_1  flight_duration  \
# 126935          83 2024-06-27 23:15:00 2024-06-28 23:18:00  1 days 00:03:00
# 65305           29 2024-04-21 22:28:00 2024-04-21 22:31:00  0 days 00:03:00
# 77282            7 2024-04-01 06:45:00 2024-04-02 06:47:00  1 days 00:02:00
# 56701           13 2024-04-03 06:45:00 2024-04-03 06:47:00  0 days 00:02:00
# 97347           30 2024-04-28 08:37:00 2024-04-28 08:40:00  0 days 00:03:00
#
#        Hours Minutes Flight_Time Fly_WeekDay  flight_duration_value
# 126935  21.0       3        21.0           4                    0.0
# 65305   27.0       3        27.0           7                    0.0
# 77282   21.0       2        21.0           1                    0.0
# 56701   21.0       2        21.0           3                    0.0
# 97347   27.0       3        27.0           7                    0.0
#
# [5 rows x 33 columns]

# %%
df.loc[df['City_Route']=='New York City - Los Angeles', 'flight_duration_value'] = df['flight_duration_value'] + 3
df.loc[df['City_Route']=='Los Angeles - New York City', 'flight_duration_value'] = df['flight_duration_value'] - 3

# %%
df['diff'] = df['Flight_Time'] - df['flight_duration_value']
df['diff'] = round(df['diff'],1)
df.sort_values('diff', ascending=False)
# Out:
#        Report_Run_Time      carrier from_loc to_loc     stop  price  \
# 74225       2024-03-25       Spirit      LAX    EWR   1 stop  184.0
# 88563       2024-03-28       Spirit      EWR    LAX   1 stop  507.0
# 92437       2024-03-28  Third Party      LAX    EWR  2 stops  258.0
# 38063       2024-03-17       Spirit      LAX    EWR   1 stop  213.0
# 111745      2024-04-02  Third Party      LAX    EWR  2 stops  198.0
# ...                ...          ...      ...    ...      ...    ...
# 45214       2024-03-18        Delta      JFK    LAX  Nonstop  284.0
# 135294      2024-04-06        Delta      LAX    JFK  Nonstop  274.0
# 1030        2024-03-10     American      EWR    LAX   1 stop  403.0
# 49511       2024-03-19       Spirit      EWR    LAX  2 stops  363.0
# 123934      2024-04-04       Spirit      EWR    LAX   1 stop  375.0
#
#        from_timestamp to_timestamp  from_date    to_date  ... Days_to_Fly  \
# 74225        21:37:00     09:57:00 2024-05-12 2024-05-13  ...          48
# 88563        12:00:00     22:46:00 2024-03-29 2024-03-29  ...           1
# 92437        06:45:00     10:08:00 2024-04-05 2024-04-05  ...           8
# 123887 2024-06-29 22:59:00 2024-06-30 20:08:00 0 days 21:09:00   NaN        0
#
#        Flight_Time Fly_WeekDay flight_duration_value diff
# 1030           8.2           4                   9.2 -1.0
# 49468          NaN           7                  24.1  NaN
# 123887         NaN           6                  24.2  NaN
#
# [3 rows x 35 columns]

# %%
df[df['Flight_Time'].isnull()]
# Out:
#          index Report_Run_Time carrier from_loc to_loc     stop  price  \
# 49468    49511      2024-03-19  Spirit      EWR    LAX  2 stops  363.0
# 123887  123934      2024-04-04  Spirit      EWR    LAX   1 stop  375.0
#
#        from_timestamp to_timestamp  from_date  ... Days_to_Fly  \
# 49468        22:09:00     19:15:00 2024-05-19  ...          61
# 123887       22:59:00     20:08:00 2024-06-29  ...          86
#
#           from_timestamp_1      to_timestamp_1 flight_duration Hours  Minutes  \
# 49468  2024-05-19 22:09:00 2024-05-20 19:15:00 0 days 21:06:00   NaN        0
# 123887 2024-06-29 22:59:00 2024-06-30 20:08:00 0 days 21:09:00   NaN        0
#
#        Flight_Time Fly_WeekDay flight_duration_value diff
# 49468          NaN           7                  24.1  NaN
# 123887         NaN           6                  24.2  NaN
#
# [2 rows x 35 columns]

# %%
df.loc[df['Flight_Time'].isnull(),'Flight_Time'] = df['flight_duration_value']

# %%
df[df['Flight_Time'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, Report_Run_Time, carrier, from_loc, to_loc, stop, price, from_timestamp, to_timestamp, from_date, to_date, carbon_emission, overhead_bin, layover, details, round_trip_duration, Airport_Route, From_City, To_City, City_Route, from_hour, from_hour_segment, to_hour, to_hour_segment, Holiday, Days_to_Fly, from_timestamp_1, to_timestamp_1, flight_duration, Hours, Minutes, Flight_Time, Fly_WeekDay, flight_duration_value, diff]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ## 7.To timestamp

# %%
df.head()
# Out:
#    index Report_Run_Time  carrier from_loc to_loc     stop  price  \
# 0      0      2024-03-10   Spirit      EWR    LAX  Nonstop  211.0
# 1      1      2024-03-10   Alaska      EWR    LAX  Nonstop  297.0
# 2      2      2024-03-10  JetBlue      EWR    LAX  Nonstop  298.0
# 3      3      2024-03-10   United      EWR    LAX  Nonstop  302.0
# 4      4      2024-03-10   Spirit      LGA    LAX   1 stop  269.0
#
#   from_timestamp to_timestamp  from_date  ... Days_to_Fly    from_timestamp_1  \
# 0       06:47:00     10:15:00 2024-03-28  ...          18 2024-03-28 06:47:00
# 1       07:30:00     10:48:00 2024-03-28  ...          18 2024-03-28 07:30:00
# 2       05:15:00     08:30:00 2024-03-28  ...          18 2024-03-28 05:15:00
# 3       12:00:00     15:24:00 2024-03-28  ...          18 2024-03-28 12:00:00
# 4       16:29:00     17:00:00 2024-03-28  ...          18 2024-03-28 16:29:00
#
#        to_timestamp_1 flight_duration Hours  Minutes Flight_Time Fly_WeekDay  \
# 0 2024-03-28 10:15:00 0 days 03:28:00   6.0       28         6.5           4
# 1 2024-03-28 10:48:00 0 days 03:18:00   6.0       18         6.3           4
# 2 2024-03-28 08:30:00 0 days 03:15:00   6.0       15         6.2           4
# 3 2024-03-28 15:24:00 0 days 03:24:00   6.0       24         6.4           4
# 4 2024-03-28 17:00:00 0 days 00:31:00  27.0       31        27.5           4
#
#   flight_duration_value  diff
# 0                   6.5   0.0
# 1                   6.3   0.0
# 2                   6.2   0.0
# 3                   6.4   0.0
# 4                   3.5  24.0
#
# [5 rows x 35 columns]

# %%
df['to_timestamp'] = df['from_timestamp_1'] + pd.to_timedelta(df['Hours'], unit='hours') + pd.to_timedelta(df['Minutes'], unit='minutes')

# %%
df.columns
# Out:
# Index(['index', 'Report_Run_Time', 'carrier', 'from_loc', 'to_loc', 'stop',
#        'price', 'from_timestamp', 'to_timestamp', 'from_date', 'to_date',
#        'carbon_emission', 'overhead_bin', 'layover', 'details',
#        'round_trip_duration', 'Airport_Route', 'From_City', 'To_City',
#        'City_Route', 'from_hour', 'from_hour_segment', 'to_hour',
#        'to_hour_segment', 'Holiday', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'flight_duration', 'Hours', 'Minutes', 'Flight_Time',
#        'Fly_WeekDay', 'flight_duration_value', 'diff'],
#       dtype='object')

# %%
df[['City_Route','from_timestamp', 'to_timestamp', 'from_date', 'to_date',
       'from_hour', 'from_hour_segment', 'to_hour',
       'to_hour_segment', 'from_timestamp_1',
       'to_timestamp_1', 'flight_duration', 'Hours', 'Minutes', 'Flight_Time',
       'Fly_WeekDay', 'flight_duration_value', 'diff']]
# Out:
#                          City_Route from_timestamp        to_timestamp  \
# 0       New York City - Los Angeles       06:47:00 2024-03-28 13:15:00
# 1       New York City - Los Angeles       07:30:00 2024-03-28 13:48:00
# 2       New York City - Los Angeles       05:15:00 2024-03-28 11:30:00
# 3       New York City - Los Angeles       12:00:00 2024-03-28 18:24:00
# 4       New York City - Los Angeles       16:29:00 2024-03-29 20:00:00
# ...                             ...            ...                 ...
# 135242  Los Angeles - New York City       10:20:00 2024-07-04 15:59:00
# 135243  Los Angeles - New York City       11:20:00 2024-07-04 16:49:00
# 135244  Los Angeles - New York City       06:00:00 2024-07-04 11:35:00
# 135245  Los Angeles - New York City       09:20:00 2024-07-04 15:15:00
# 135246  Los Angeles - New York City       16:00:00 2024-07-04 21:37:00
#
#         from_date    to_date  from_hour from_hour_segment  to_hour  \
# 0      2024-03-28 2024-03-28          6    3. 6 AM - 9 AM       10
# 1      2024-03-28 2024-03-28          7    3. 6 AM - 9 AM       10
# 2      2024-03-28 2024-03-28          5    2. 3 AM - 6 AM        8
# 3      2024-03-28 2024-03-28         12   5. 12 PM - 3 PM       15
# 4      2024-03-28 2024-03-28         16    6. 3 PM - 6 PM       17
# ...           ...        ...        ...               ...      ...
# 135242 2024-07-04 2024-07-05         10   4. 9 AM - 12 PM       18
# 135243 2024-07-04 2024-07-05         11   4. 9 AM - 12 PM       19
# 135244 2024-07-04 2024-07-05          6    3. 6 AM - 9 AM       14
# 135245 2024-07-04 2024-07-05          9   4. 9 AM - 12 PM       18
# 135246 2024-07-04 2024-07-05         16    6. 3 PM - 6 PM        0
#
#         to_hour_segment    from_timestamp_1      to_timestamp_1  \
# 0       4. 9 AM - 12 PM 2024-03-28 06:47:00 2024-03-28 10:15:00
# 1       4. 9 AM - 12 PM 2024-03-28 07:30:00 2024-03-28 10:48:00
# 2        3. 6 AM - 9 AM 2024-03-28 05:15:00 2024-03-28 08:30:00
# 3        6. 3 PM - 6 PM 2024-03-28 12:00:00 2024-03-28 15:24:00
# 4        6. 3 PM - 6 PM 2024-03-28 16:29:00 2024-03-28 17:00:00
# ...                 ...                 ...                 ...
# 135242   7. 6 PM - 9 PM 2024-07-04 10:20:00 2024-07-05 18:59:00
# 135243   7. 6 PM - 9 PM 2024-07-04 11:20:00 2024-07-05 19:49:00
# 135244  5. 12 PM - 3 PM 2024-07-04 06:00:00 2024-07-05 14:35:00
# 135245   7. 6 PM - 9 PM 2024-07-04 09:20:00 2024-07-05 18:15:00
# 135246  1. 12 AM - 3 AM 2024-07-04 16:00:00 2024-07-05 00:37:00
#
#        flight_duration  Hours  Minutes  Flight_Time  Fly_WeekDay  \
# 0      0 days 03:28:00    6.0       28          6.5            4
# 1      0 days 03:18:00    6.0       18          6.3            4
# 2      0 days 03:15:00    6.0       15          6.2            4
# 3      0 days 03:24:00    6.0       24          6.4            4
# 4      0 days 00:31:00   27.0       31         27.5            4
# ...                ...    ...      ...          ...          ...
# 135242 1 days 08:39:00    5.0       39          5.6            4
# 135243 1 days 08:29:00    5.0       29          5.5            4
# 135244 1 days 08:35:00    5.0       35          5.6            4
# 135245 1 days 08:55:00    5.0       55          5.9            4
# 135246 0 days 08:37:00    5.0       37          5.6            4
#
#         flight_duration_value  diff
# 0                         6.5   0.0
# 1                         6.3   0.0
# 2                         6.2   0.0
# 3                         6.4   0.0
# 4                         3.5  24.0
# ...                       ...   ...
# 135242                    5.6   0.0
# 135243                    5.5   0.0
# 135244                    5.6   0.0
# 135245                    5.9   0.0
# 135246                    5.6   0.0
#
# [135247 rows x 18 columns]

# %%
df.loc[df['City_Route']=='New York City - Los Angeles', 'to_timestamp'] = df['to_timestamp'] - pd.to_timedelta(3, unit='hours')
df.loc[df['City_Route']=='Los Angeles - New York City', 'to_timestamp'] = df['to_timestamp'] + pd.to_timedelta(3, unit='hours')

# %%
df[['City_Route','from_timestamp', 'to_timestamp', 'from_date', 'to_date',
       'from_hour', 'from_hour_segment', 'to_hour',
       'to_hour_segment', 'from_timestamp_1',
       'to_timestamp_1', 'flight_duration', 'Hours', 'Minutes', 'Flight_Time',
       'Fly_WeekDay', 'flight_duration_value', 'diff']]
# Out:
#                          City_Route from_timestamp        to_timestamp  \
# 0       New York City - Los Angeles       06:47:00 2024-03-28 10:15:00
# 1       New York City - Los Angeles       07:30:00 2024-03-28 10:48:00
# 2       New York City - Los Angeles       05:15:00 2024-03-28 08:30:00
# 3       New York City - Los Angeles       12:00:00 2024-03-28 15:24:00
# 4       New York City - Los Angeles       16:29:00 2024-03-29 17:00:00
# ...                             ...            ...                 ...
# 135242  Los Angeles - New York City       10:20:00 2024-07-04 18:59:00
# 135243  Los Angeles - New York City       11:20:00 2024-07-04 19:49:00
# %%
df['to_hour'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='to_hour'>

# %%
df.loc[(df['to_hour'] >= 0) & (df['to_hour'] < 3),'to_hour_segment'] = '1. 12 AM - 3 AM'
df.loc[(df['to_hour'] >= 3) & (df['to_hour'] < 6),'to_hour_segment'] = '2. 3 AM - 6 AM'
df.loc[(df['to_hour'] >= 6) & (df['to_hour'] < 9),'to_hour_segment'] = '3. 6 AM - 9 AM'
df.loc[(df['to_hour'] >= 9) & (df['to_hour'] < 12),'to_hour_segment'] = '4. 9 AM - 12 PM'
df.loc[(df['to_hour'] >= 12) & (df['to_hour'] < 15),'to_hour_segment'] = '5. 12 PM - 3 PM'
df.loc[(df['to_hour'] >= 15) & (df['to_hour'] < 18),'to_hour_segment'] = '6. 3 PM - 6 PM'
df.loc[(df['to_hour'] >= 18) & (df['to_hour'] < 21),'to_hour_segment'] = '7. 6 PM - 9 PM'
df.loc[(df['to_hour'] >= 21) & (df['to_hour'] < 24),'to_hour_segment'] = '8. 9 PM - 12 AM'

# %%
df['to_hour_segment'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='to_hour_segment'>

# %%
df.columns
# Out:
# Index(['index', 'Report_Run_Time', 'carrier', 'from_loc', 'to_loc', 'stop',
#        'price', 'from_timestamp', 'to_timestamp', 'from_date', 'to_date',
#        'carbon_emission', 'overhead_bin', 'layover', 'details',
#        'round_trip_duration', 'Airport_Route', 'From_City', 'To_City',
#        'City_Route', 'from_hour', 'from_hour_segment', 'to_hour',
#        'to_hour_segment', 'Holiday', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'flight_duration', 'Hours', 'Minutes', 'Flight_Time',
#        'Fly_WeekDay', 'flight_duration_value', 'diff'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sns.histplot(df['Flight_Time'], kde=True, bins=50)

plt.subplot(1,2,2)
sns.boxplot(df['Flight_Time'])

plt.tight_layout()

# %%
sns.histplot(df['Flight_Time'], kde=True, bins=50, cumulative=True)
# Out:
# <Axes: xlabel='Flight_Time', ylabel='Count'>

# %%
flight_times = df['Flight_Time'].dropna()

hist, bins = np.histogram(flight_times, bins=50)

hist_df = pd.DataFrame({'Bin_Start': bins[:-1], 'Bin_End': bins[1:], 'Count': hist})

hist_df['Cumulative'] = hist_df['Count'].cumsum()

total_count = hist_df['Count'].sum()
hist_df['Cumulative %'] = (hist_df['Cumulative'] / total_count) * 100

hist_df
# Out:
#     Bin_Start  Bin_End  Count  Cumulative  Cumulative %
# 0       2.500    3.388      1           1      0.000739
# 1       3.388    4.276      1           2      0.001479
# 2       4.276    5.164   1909        1911      1.412970
# 3       5.164    6.052  73566       75477     55.806783
# 4       6.052    6.940  41932      117409     86.810798
# 5       6.940    7.828   3704      121113     89.549491
# 6       7.828    8.716   4015      125128     92.518133
# 7       8.716    9.604   1586      126714     93.690803
# 8       9.604   10.492   1565      128279     94.847945
# 9      10.492   11.380   1272      129551     95.788446
# 10     11.380   12.268   1157      130708     96.643918
# 11     12.268   13.156    473      131181     96.993649
# 12     13.156   14.044    530      131711     97.385524
# 13     14.044   14.932    504      132215     97.758176
# 14     14.932   15.820    441      132656     98.084246
# 15     15.820   16.708    235      132891     98.258002
# 16     16.708   17.596    145      133036     98.365213
# 17     17.596   18.484    424      133460     98.678714
# 18     18.484   19.372    229      133689     98.848034
# 19     19.372   20.260    156      133845     98.963378
# 20     20.260   21.148    129      133974     99.058759
# 21     21.148   22.036     93      134067     99.127522
# 22     22.036   22.924     76      134143     99.183716
# 23     22.924   23.812    246      134389     99.365605
# 24     23.812   24.700     76      134465     99.421799
# 25     24.700   25.588    266      134731     99.618476
# 26     25.588   26.476     35      134766     99.644354
# 27     26.476   27.364     43      134809     99.676148
# 28     27.364   28.252     46      134855     99.710160
# 29     28.252   29.140     35      134890     99.736039
# 30     29.140   30.028     57      134947     99.778184
# 31     30.028   30.916     13      134960     99.787796
# 32     30.916   31.804     14      134974     99.798147
# 33     31.804   32.692     16      134990     99.809977
# 34     32.692   33.580     91      135081     99.877262
# 35     33.580   34.468     43      135124     99.909055
# 36     34.468   35.356     14      135138     99.919407
# 37     35.356   36.244     18      135156     99.932716
# 38     36.244   37.132      5      135161     99.936413
# 39     37.132   38.020     30      135191     99.958594
# 40     38.020   38.908     26      135217     99.977818
# 41     38.908   39.796      9      135226     99.984473
# 42     39.796   40.684      2      135228     99.985952
# 43     40.684   41.572     12      135240     99.994824
# 44     41.572   42.460      0      135240     99.994824
# 45     42.460   43.348      1      135241     99.995564
# 46     43.348   44.236      5      135246     99.999261
# 47     44.236   45.124      0      135246     99.999261
# 48     45.124   46.012      0      135246     99.999261
# 49     46.012   46.900      1      135247    100.000000

# %%
sns.histplot(np.log1p(df['Flight_Time']), kde=True, bins=50)
# Out:
# <Axes: xlabel='Flight_Time', ylabel='Count'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['Flight_Time'].quantile(0.25)
Q3 = df['Flight_Time'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f'lower_bound is {lower_bound}')
print(f'upper_bound is {upper_bound}')


# Identify outliers
outliers = df[(df['Flight_Time'] < lower_bound) | (df['Flight_Time'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['Flight_Time'].describe()

num_outliers, outliers_price_stats
# Out:
# lower_bound is 4.300000000000001
# upper_bound is 7.5
# (15852,
#  count    15852.000000
#  mean        11.980122
#  std          5.577335
#  min          2.500000
#  25%          8.300000
#  50%         10.000000
#  75%         13.400000
#  max         46.900000
#  Name: Flight_Time, dtype: float64)

# %%
df[df['Flight_Time']>20]
# Out:
#          index Report_Run_Time      carrier from_loc to_loc     stop  price  \
# 4            4      2024-03-10       Spirit      LGA    LAX   1 stop  269.0
# 99          99      2024-03-10       Spirit      EWR    LAX   1 stop  245.0
# 146        146      2024-03-10  Third Party      LGA    LAX   1 stop  242.0
# 660        660      2024-03-10       Spirit      EWR    LAX   1 stop  180.0
# %%
# df['flight_duration_value'].mode()

# %% [markdown]
# ### Observation
#
# - High number of the flight duration is around 5 to 6 hours.

# %%
df.columns
# Out:
# Index(['index', 'Report_Run_Time', 'carrier', 'from_loc', 'to_loc', 'stop',
#        'price', 'from_timestamp', 'to_timestamp', 'from_date', 'to_date',
#        'carbon_emission', 'overhead_bin', 'layover', 'details',
#        'round_trip_duration', 'Airport_Route', 'From_City', 'To_City',
#        'City_Route', 'from_hour', 'from_hour_segment', 'to_hour',
#        'to_hour_segment', 'Holiday', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'flight_duration', 'Hours', 'Minutes', 'Flight_Time',
#        'Fly_WeekDay', 'flight_duration_value', 'diff'],
#       dtype='object')

# %%
df['flight_duration_value'] = df['Flight_Time']

# %%
df = df.drop(columns=['Flight_Time','Hours', 'Minutes','diff'])

# %%
df.columns
# Out:
# Index(['index', 'Report_Run_Time', 'carrier', 'from_loc', 'to_loc', 'stop',
#        'price', 'from_timestamp', 'to_timestamp', 'from_date', 'to_date',
#        'carbon_emission', 'overhead_bin', 'layover', 'details',
#        'round_trip_duration', 'Airport_Route', 'From_City', 'To_City',
#        'City_Route', 'from_hour', 'from_hour_segment', 'to_hour',
#        'to_hour_segment', 'Holiday', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'flight_duration', 'Fly_WeekDay',
#        'flight_duration_value'],
#       dtype='object')

# %% [markdown]
# ## 10.Carbon Emission

# %%
df.carbon_emission.unique()
# Out:
# array(['Carbon emissions estimate: 293 kilograms. -18% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 272 kilograms. -24% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 422 kilograms. +18% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 427 kilograms. +19% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 338 kilograms. -6% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 295 kilograms. -18% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 317 kilograms. -12% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 246 kilograms. -31% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 410 kilograms. +14% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 406 kilograms. +13% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 408 kilograms. +14% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 346 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 273 kilograms. -24% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 255 kilograms. -29% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 314 kilograms. -13% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 556 kilograms. +55% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 215 kilograms. -40% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 290 kilograms. -19% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 402 kilograms. +12% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 421 kilograms. +17% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 277 kilograms. -23% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 350 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 343 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 328 kilograms. -9% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 416 kilograms. +16% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 548 kilograms. +53% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 341 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 264 kilograms. -26% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 307 kilograms. -14% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 251 kilograms. -30% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 333 kilograms. -7% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 267 kilograms. -26% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 256 kilograms. -29% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 283 kilograms. -21% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 360 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 395 kilograms. +10% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 313 kilograms. -13% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 291 kilograms. -19% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 278 kilograms. -23% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 534 kilograms. +49% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 289 kilograms. -19% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 282 kilograms. -21% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 262 kilograms. -27% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 288 kilograms. -20% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 326 kilograms. -9% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 257 kilograms. -28% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 411 kilograms. +14% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,351 kilograms. +1,948% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 361 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 356 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 392 kilograms. +9% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 538 kilograms. +50% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 252 kilograms. -30% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 390 kilograms. +9% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 301 kilograms. -16% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 263 kilograms. -27% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 280 kilograms. -22% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 296 kilograms. -18% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 506 kilograms. +41% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 325 kilograms. -9% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 370 kilograms. Average emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 298 kilograms. -17% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 302 kilograms. -16% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 285 kilograms. -21% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 329 kilograms. -8% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 415 kilograms. +16% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 308 kilograms. -14% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 434 kilograms. +21% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 311 kilograms. -13% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,376 kilograms. +1,955% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 297 kilograms. -17% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7
emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 643 kilograms. +80% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 1,332 kilograms. +272% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 604 kilograms. +69% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 1,227 kilograms. +243% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 429 kilograms. +20% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 241 kilograms. -33% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 248 kilograms. -31% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 531 kilograms. +48% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,376 kilograms. +1,960% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,501 kilograms. +1,995% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,194 kilograms. +1,909% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,213 kilograms. +1,915% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 270 kilograms. -23% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 550 kilograms. +54% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 459 kilograms. +28% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 453 kilograms. +27% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,258 kilograms. +1,927% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 8,969 kilograms. +2,405% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 414 kilograms. +16% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 8,934 kilograms. +2,396% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,368 kilograms. +1,958% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 7,381 kilograms. +1,962% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 528 kilograms. +47% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 500 kilograms. +39% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 449 kilograms. +25% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 375 kilograms. +7% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 585 kilograms. +66% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 381 kilograms. +6% emissions. Learn more about this emissions estimate',
#        'Carbon emissions estimate: 656 kilograms. +83% emissions. Learn more about this emissions estimate'],
#       dtype=object)

# %%
df['carbon_array'] = df.carbon_emission.str.split(".")

# %%
def get_first_value(arr):
    if len(arr) > 0:
        return arr[0]
    else:
        return None

df['Carbon emissions estimate'] = df['carbon_array'].apply(lambda x: get_first_value(x))

# %%
df.tail(2)
# Out:
#          index Report_Run_Time carrier from_loc to_loc     stop  price  \
# 135245  135293      2024-04-06   Delta      LAX    JFK  Nonstop  274.0
# 135246  135294      2024-04-06   Delta      LAX    JFK  Nonstop  274.0
#
#        from_timestamp        to_timestamp  from_date  ...  to_hour_segment  \
# 135245       09:20:00 2024-07-04 18:15:00 2024-07-04  ...   7. 6 PM - 9 PM
# 135246       16:00:00 2024-07-05 00:37:00 2024-07-04  ...  1. 12 AM - 3 AM
#
#         Holiday Days_to_Fly    from_timestamp_1      to_timestamp_1  \
# 135245  Holiday          89 2024-07-04 09:20:00 2024-07-05 18:15:00
# 135246  Holiday          89 2024-07-04 16:00:00 2024-07-05 00:37:00
#
#         flight_duration Fly_WeekDay flight_duration_value  \
# 135245  1 days 08:55:00           4                   5.9
# 135246  0 days 08:37:00           4                   5.6
#
#                                              carbon_array  \
# 135245  [Carbon emissions estimate: 298 kilograms,  -1...
# 135246  [Carbon emissions estimate: 298 kilograms,  -1...
#
#                        Carbon emissions estimate
# 135245  Carbon emissions estimate: 298 kilograms
# 135246  Carbon emissions estimate: 298 kilograms
#
# [2 rows x 33 columns]

# %%
df[['carbon_emission', 'carbon_array']]
# Out:
#                                           carbon_emission  \
# 0       Carbon emissions estimate: 293 kilograms. -18%...
# 1       Carbon emissions estimate: 272 kilograms. -24%...
# 2       Carbon emissions estimate: 422 kilograms. +18%...
# 3       Carbon emissions estimate: 427 kilograms. +19%...
# 4       Carbon emissions estimate: 338 kilograms. -6% ...
# ...                                                   ...
# 135242  Carbon emissions estimate: 300 kilograms. -15%...
# 135243  Carbon emissions estimate: 370 kilograms. Aver...
# 135244  Carbon emissions estimate: 298 kilograms. -15%...
# 135245  Carbon emissions estimate: 298 kilograms. -15%...
# 135246  Carbon emissions estimate: 298 kilograms. -15%...
#
#                                              carbon_array
# 0       [Carbon emissions estimate: 293 kilograms,  -1...
# 1       [Carbon emissions estimate: 272 kilograms,  -2...
# 2       [Carbon emissions estimate: 422 kilograms,  +1...
# 3       [Carbon emissions estimate: 427 kilograms,  +1...
# 4       [Carbon emissions estimate: 338 kilograms,  -6...
# ...                                                   ...
# 135242  [Carbon emissions estimate: 300 kilograms,  -1...
# 135243  [Carbon emissions estimate: 370 kilograms,  Av...
# 135244  [Carbon emissions estimate: 298 kilograms,  -1...
# 135245  [Carbon emissions estimate: 298 kilograms,  -1...
# 135246  [Carbon emissions estimate: 298 kilograms,  -1...
#
# [135247 rows x 2 columns]

# %%
def get_second_value(arr):
    if len(arr) > 1:
        return arr[1]
    else:
        return None

df['carbon_emission_1'] = df['carbon_array'].apply(lambda x: get_second_value(x))

# %%
df[['carbon_emission','carbon_emission_1']]
# Out:
#                                           carbon_emission   carbon_emission_1
# 0       Carbon emissions estimate: 293 kilograms. -18%...      -18% emissions
# 1       Carbon emissions estimate: 272 kilograms. -24%...      -24% emissions
# 2       Carbon emissions estimate: 422 kilograms. +18%...      +18% emissions
# 3       Carbon emissions estimate: 427 kilograms. +19%...      +19% emissions
# 4       Carbon emissions estimate: 338 kilograms. -6% ...       -6% emissions
# ...                                                   ...                 ...
# 135242  Carbon emissions estimate: 300 kilograms. -15%...      -15% emissions
# 135243  Carbon emissions estimate: 370 kilograms. Aver...   Average emissions
# 135244  Carbon emissions estimate: 298 kilograms. -15%...      -15% emissions
# 135245  Carbon emissions estimate: 298 kilograms. -15%...      -15% emissions
# 135246  Carbon emissions estimate: 298 kilograms. -15%...      -15% emissions
#
# [135247 rows x 2 columns]

# %% [markdown]
# ### 10.1 Carbon Emission % (New Column)

# %%
df['carbon_emission%'] = df['carbon_emission_1'].fillna(df['carbon_emission'])

# %%
df.head()
# Out:
#    index Report_Run_Time  carrier from_loc to_loc     stop  price  \
# 0      0      2024-03-10   Spirit      EWR    LAX  Nonstop  211.0
# 1      1      2024-03-10   Alaska      EWR    LAX  Nonstop  297.0
# 2      2      2024-03-10  JetBlue      EWR    LAX  Nonstop  298.0
# 3      3      2024-03-10   United      EWR    LAX  Nonstop  302.0
# 4      4      2024-03-10   Spirit      LGA    LAX   1 stop  269.0
#
#   from_timestamp        to_timestamp  from_date  ... Days_to_Fly  \
# 0       06:47:00 2024-03-28 10:15:00 2024-03-28  ...          18
# 1       07:30:00 2024-03-28 10:48:00 2024-03-28  ...          18
# 2       05:15:00 2024-03-28 08:30:00 2024-03-28  ...          18
# 3       12:00:00 2024-03-28 15:24:00 2024-03-28  ...          18
# 4       16:29:00 2024-03-29 17:00:00 2024-03-28  ...          18
#
#      from_timestamp_1      to_timestamp_1 flight_duration Fly_WeekDay  \
# 0 2024-03-28 06:47:00 2024-03-28 10:15:00 0 days 03:28:00           4
# 1 2024-03-28 07:30:00 2024-03-28 10:48:00 0 days 03:18:00           4
# 2 2024-03-28 05:15:00 2024-03-28 08:30:00 0 days 03:15:00           4
# 3 2024-03-28 12:00:00 2024-03-28 15:24:00 0 days 03:24:00           4
# 4 2024-03-28 16:29:00 2024-03-28 17:00:00 0 days 00:31:00           4
#
#    flight_duration_value                                       carbon_array  \
# 0                    6.5  [Carbon emissions estimate: 293 kilograms,  -1...
# 1                    6.3  [Carbon emissions estimate: 272 kilograms,  -2...
# 2                    6.2  [Carbon emissions estimate: 422 kilograms,  +1...
# 3                    6.4  [Carbon emissions estimate: 427 kilograms,  +1...
# 4                   27.5  [Carbon emissions estimate: 338 kilograms,  -6...
#
#                   Carbon emissions estimate carbon_emission_1 carbon_emission%
# 0  Carbon emissions estimate: 293 kilograms    -18% emissions   -18% emissions
# 1  Carbon emissions estimate: 272 kilograms    -24% emissions   -24% emissions
# 2  Carbon emissions estimate: 422 kilograms    +18% emissions   +18% emissions
# 3  Carbon emissions estimate: 427 kilograms    +19% emissions   +19% emissions
# 4  Carbon emissions estimate: 338 kilograms     -6% emissions    -6% emissions
#
# [5 rows x 35 columns]

# %%
df[['Carbon emissions estimate', 'carbon_emission%']]
# Out:
#                        Carbon emissions estimate    carbon_emission%
# 0       Carbon emissions estimate: 293 kilograms      -18% emissions
# 1       Carbon emissions estimate: 272 kilograms      -24% emissions
# 2       Carbon emissions estimate: 422 kilograms      +18% emissions
# 3       Carbon emissions estimate: 427 kilograms      +19% emissions
# 4       Carbon emissions estimate: 338 kilograms       -6% emissions
# ...                                          ...                 ...
# 135242  Carbon emissions estimate: 300 kilograms      -15% emissions
# 135243  Carbon emissions estimate: 370 kilograms   Average emissions
# 135244  Carbon emissions estimate: 298 kilograms      -15% emissions
# 135245  Carbon emissions estimate: 298 kilograms      -15% emissions
# 135246  Carbon emissions estimate: 298 kilograms      -15% emissions
#
# [135247 rows x 2 columns]

# %%
df['Carbon emissions estimate'] = df['Carbon emissions estimate'].str.replace('Carbon emissions estimate: ','')
df['carbon_emission%'] = df['carbon_emission%'].str.replace(' emissions','')

# %%
df[['Carbon emissions estimate', 'carbon_emission%']]
# Out:
#        Carbon emissions estimate carbon_emission%
# 0                  293 kilograms             -18%
# 1                  272 kilograms             -24%
# 2                  422 kilograms             +18%
# 3                  427 kilograms             +19%
# 4                  338 kilograms              -6%
# ...                          ...              ...
# 135242             300 kilograms             -15%
# 135243             370 kilograms          Average
# 135244             298 kilograms             -15%
# 135245             298 kilograms             -15%
# 135246             298 kilograms             -15%
#
# [135247 rows x 2 columns]

# %%
df['Carbon emissions estimate'].unique()
# Out:
# array(['293 kilograms', '272 kilograms', '422 kilograms', '427 kilograms',
#        '338 kilograms', '295 kilograms', '317 kilograms', '246 kilograms',
#        '410 kilograms', '406 kilograms', '408 kilograms', '346 kilograms',
#        '273 kilograms', '255 kilograms', '314 kilograms', '556 kilograms',
#        '215 kilograms', '290 kilograms', '402 kilograms', '421 kilograms',
#        '277 kilograms', '350 kilograms', '343 kilograms', '328 kilograms',
#        '416 kilograms', '548 kilograms', '341 kilograms', '264 kilograms',
#        '307 kilograms', '251 kilograms', '333 kilograms', '267 kilograms',
#        '256 kilograms', '283 kilograms', '360 kilograms', '395 kilograms',
#        '313 kilograms', '291 kilograms', '278 kilograms', '534 kilograms',
#        '289 kilograms', '282 kilograms', '262 kilograms', '288 kilograms',
#        '412', '242', '405', '384', '533', '249', '299', '260', '253',
#        '424', '368', '275', '258', '306', '7,368', '327', '371', '400',
#        '382', '239', '531', '378', '381', '259', '248', '250', '315',
#        '292', '238', '399', '323', '529', '441', '398', '396', '236',
#        '332', '545', '210', '245', '268', '352', '348', '435', '496',
#        '241', '404', '537', '309', '244', '407', '321', '418', '349',
#        '429', '312', '431', '354', '358', '266', '451', '428', '287',
#        '335', '372', '342', '353', '403', '344', '817', '366', '387',
#        '300', '443', '364', '271', '532', '7,263', '471', '420', '331',
#        '270', '389', '363', '520', '454', '310', '340', '337', '369',
#        '522', '519', '365', '423', '336', '388', '447', '835', '469',
#        '8,952', '318', '540', '304', '', '499', '377', '373', '7,194',
#        '286', '516', '680', '391', '274', '637', '651', '339', '708',
#        '536', '394', '493', '7,258', '803', '430', '7,386', '334', '385',
#        '561', '393', '455', '433', '351', '612', '822', '380', '475',
#        '504', '284', '375', '513', '401', '432', '490', '8,817', '555',
#        '685', '439', '485', '691', '1,094', '1,255', '436', '616', '426',
#        '7,213', '7,381', '560', '450', '468', '446', '608', '984', '713',
#        '449', '597', '547', '494', '8,934', '675', '515', '473', '946',
#        '517', '716', '453', '805', '414', '7,380', '265', '462', '374',
#        '452', '425', '476', '569', '442', '461', '413', '276', '7,286',
#        '7,385', '261', '465', '666', '464', '661', '550', '437', '509',
#        '440', '478', '458', '8,969', '498', '444', '8,977', '483', '474',
#        '463', '541', '512', '511', '7,501', '7,507', '640', '514', '503',
#        '417', '658', '799', '643', '500', '240', '472', '530', '677',
#        '8,844', '7,269', '1,332', '604', '1,227', '459', '528', '585',
#        '656'], dtype=object)

# %% [markdown]
# ### 10.2 Carbon emissions estimate num (New Column)

# %%
df['Carbon emissions estimate num'] = pd.to_numeric(df['Carbon emissions estimate'], errors='coerce').astype('Int64')

# %%
df.loc[(df['Carbon emissions estimate'].str.contains('1'))
       | (df['Carbon emissions estimate'].str.contains('2'))
       | (df['Carbon emissions estimate'].str.contains('3'))
       | (df['Carbon emissions estimate'].str.contains('4'))
       | (df['Carbon emissions estimate'].str.contains('5'))
       | (df['Carbon emissions estimate'].str.contains('6'))
       | (df['Carbon emissions estimate'].str.contains('7'))
       | (df['Carbon emissions estimate'].str.contains('8'))
       | (df['Carbon emissions estimate'].str.contains('9')),
       'Carbon emissions estimate'] = df['Carbon emissions estimate num']

# %%
df['Carbon emissions estimate'].unique()
# Out:
# array([293, 272, 422, 427, 338, 295, 317, 246, 410, 406, 408, 346, 273,
#        255, 314, 556, 215, 290, 402, 421, 277, 350, 343, 328, 416, 548,
#        341, 264, 307, 251, 333, 267, 256, 283, 360, 395, 313, 291, 278,
#        534, 289, 282, 262, 288, 326, 257, 411, <NA>, 361, 356, 392, 538,
#        252, 390, 301, 263, 280, 296, 506, 325, 370, 298, 302, 285, 329,
#        415, 308, 434, 311, 297, 330, 383, 357, 419, 367, 279, 397, 347,
#        294, 409, 316, 281, 303, 379, 269, 319, 359, 355, 324, 362, 376,
#        345, 305, 322, 320, 386, 412, 242, 405, 384, 533, 249, 299, 260,
#        253, 424, 368, 275, 258, 306, 327, 371, 400, 382, 239, 531, 378,
#        381, 259, 248, 250, 315, 292, 238, 399, 323, 529, 441, 398, 396,
#        236, 332, 545, 210, 245, 268, 352, 348, 435, 496, 241, 404, 537,
#        309, 244, 407, 321, 418, 349, 429, 312, 431, 354, 358, 266, 451,
#        428, 287, 335, 372, 342, 353, 403, 344, 817, 366, 387, 300, 443,
#        364, 271, 532, 471, 420, 331, 270, 389, 363, 520, 454, 310, 340,
#        337, 369, 522, 519, 365, 423, 336, 388, 447, 835, 469, 318, 540,
#        304, '', 499, 377, 373, 286, 516, 680, 391, 274, 637, 651, 339,
#        708, 536, 394, 493, 803, 430, 334, 385, 561, 393, 455, 433, 351,
#        612, 822, 380, 475, 504, 284, 375, 513, 401, 432, 490, 555, 685,
#        439, 485, 691, 436, 616, 426, 560, 450, 468, 446, 608, 984, 713,
#        449, 597, 547, 494, 675, 515, 473, 946, 517, 716, 453, 805, 414,
#        265, 462, 374, 452, 425, 476, 569, 442, 461, 413, 276, 261, 465,
#        666, 464, 661, 550, 437, 509, 440, 478, 458, 498, 444, 483, 474,
#        463, 541, 512, 511, 640, 514, 503, 417, 658, 799, 643, 500, 240,
#        472, 530, 677, 604, 459, 528, 585, 656], dtype=object)

# %%
df['Carbon emissions estimate num'].unique()
# Out:
# <IntegerArray>
# [293, 272, 422, 427, 338, 295, 317, 246, 410, 406,
#  ...
#  500, 240, 472, 530, 677, 604, 459, 528, 585, 656]
# Length: 306, dtype: Int64

# %%
df['Carbon emissions estimate num'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# #### Observation
#
# - Most of the flight have carbon emission around 400 kg CO2e (Carbon dioxide equivalent)

# %%
df['carbon_emission%'].unique()
# Out:
# array([' -18%', ' -24%', ' +18%', ' +19%', ' -6%', ' -12%', ' -31%',
#        ' +14%', ' +13%', ' Average', ' -29%', ' -13%', ' +55%', ' -40%',
#        ' -19%', ' +12%', ' +17%', ' -23%', ' -9%', ' +16%', ' +53%',
#        ' -26%', ' -14%', ' -30%', ' -7%', ' -21%', ' +10%', ' +49%',
#        ' -27%', ' -20%', ' -28%', ' +1,948%', ' +9%', ' +50%', ' -16%',
#        ' -22%', ' +41%', ' -17%', ' -8%', ' +21%', ' +1,955%', ' +1,917%',
#        ' +7%', ' +11%', ' +6%', ' -25%', ' -11%', ' +2,351%', ' -10%',
#        ' -15%', ' +8%', ' +15%', ' -33%', ' +48%', ' +1,952%', ' -32%',
#        ' +51%', ' +25%', ' +20%', ' +24%', ' +22%', ' +28%', ' +132%',
#        ' +23%', ' +1,923%', ' +31%', ' +29%', ' +26%', ' +47%', ' +133%',
#        ' +45%', ' +2,394%', '', ' +39%', ' +1,904%', ' +93%', ' +81%',
#        ' +85%', ' +97%', ' +37%', ' +1,922%', ' +124%', ' +1,957%',
#        ' +59%', ' +70%', ' +129%', ' +32%', ' +40%', ' +43%', ' +52%',
#        ' +46%', ' -41%', ' +54%', ' +131%', ' +2,356%', ' +91%', ' +35%',
#        ' +92%', ' +205%', ' +250%', ' -34%', ' +130%', ' +79%', ' +74%',
#        ' +1,909%', ' +1,956%', ' +56%', ' +69%', ' +174%', ' +99%',
#        ' +27%', ' +38%', ' +1,949%', ' +30%', ' +1,898%', ' +1,911%',
#        ' +1,918%', ' +2,382%', ' +1,942%', ' +1,950%', ' +98%',
#        ' +1,916%', ' +34%', ' +90%', ' +166%', ' +1,947%', ' +2,387%',
#        ' +102%', ' +33%', ' +1,931%', ' +1,935%', ' +2,368%', ' +2,330%',
#        ' +1,900%', ' +1,887%', ' +127%', ' +1,905%', ' +1,938%',
#        ' +1,906%', ' +1,939%', ' +2,344%', ' +128%', ' +62%', ' +2,389%',
#        ' +75%', ' +61%', ' +83%', ' +1,930%', ' +84%', ' +89%', ' +87%',
#        ' +42%', ' +80%', ' +2,349%', ' +2,398%', ' +2,401%', ' +88%',
#        ' +1,989%', ' +1,991%', ' +123%', ' +1,966%', ' +1,928%',
#        ' +1,934%', ' +1,959%', ' +36%', ' +2,403%', ' +2,408%',
#        ' +1,915%', ' +1,920%', ' +94%', ' +2,371%', ' +44%', ' +1,965%',
#        ' +1,973%', ' +2,410%', ' +1,940%', ' +2,422%', ' +1,972%',
#        ' +2,419%', ' +2,377%', ' +1,921%', ' +1,926%', ' +2,415%',
#        ' +2,364%', ' +1,925%', ' +1,953%', ' +272%', ' +243%', ' +1,960%',
#        ' +1,995%', ' +1,927%', ' +2,405%', ' +2,396%', ' +1,958%',
#        ' +1,962%', ' +66%'], dtype=object)

# %% [markdown]
# ### 10.3 carbon_emission% num (New Column)

# %%
df['carbon_emission% num'] = df['carbon_emission%'].str.replace(',','')
df['carbon_emission% num'] = df['carbon_emission% num'].str.replace('%','')
df['carbon_emission% num'] = df['carbon_emission% num'].str.replace(' ','')
df['carbon_emission% num'] = df['carbon_emission% num'].str.replace('Avg','0')
df['carbon_emission% num'] = df['carbon_emission% num'].str.replace('Average','0')

# %%
df['carbon_emission% num'].unique()
# Out:
# array(['-18', '-24', '+18', '+19', '-6', '-12', '-31', '+14', '+13', '0',
#        '-29', '-13', '+55', '-40', '-19', '+12', '+17', '-23', '-9',
#        '+16', '+53', '-26', '-14', '-30', '-7', '-21', '+10', '+49',
#        '-27', '-20', '-28', '+1948', '+9', '+50', '-16', '-22', '+41',
#        '-17', '-8', '+21', '+1955', '+1917', '+7', '+11', '+6', '-25',
#        '-11', '+2351', '-10', '-15', '+8', '+15', '-33', '+48', '+1952',
#        '-32', '+51', '+25', '+20', '+24', '+22', '+28', '+132', '+23',
#        '+1923', '+31', '+29', '+26', '+47', '+133', '+45', '+2394', '',
#        '+39', '+1904', '+93', '+81', '+85', '+97', '+37', '+1922', '+124',
#        '+1957', '+59', '+70', '+129', '+32', '+40', '+43', '+52', '+46',
#        '-41', '+54', '+131', '+2356', '+91', '+35', '+92', '+205', '+250',
#        '-34', '+130', '+79', '+74', '+1909', '+1956', '+56', '+69',
#        '+174', '+99', '+27', '+38', '+1949', '+30', '+1898', '+1911',
#        '+1918', '+2382', '+1942', '+1950', '+98', '+1916', '+34', '+90',
#        '+166', '+1947', '+2387', '+102', '+33', '+1931', '+1935', '+2368',
#        '+2330', '+1900', '+1887', '+127', '+1905', '+1938', '+1906',
#        '+1939', '+2344', '+128', '+62', '+2389', '+75', '+61', '+83',
#        '+1930', '+84', '+89', '+87', '+42', '+80', '+2349', '+2398',
#        '+2401', '+88', '+1989', '+1991', '+123', '+1966', '+1928',
#        '+1934', '+1959', '+36', '+2403', '+2408', '+1915', '+1920', '+94',
#        '+2371', '+44', '+1965', '+1973', '+2410', '+1940', '+2422',
#        '+1972', '+2419', '+2377', '+1921', '+1926', '+2415', '+2364',
#        '+1925', '+1953', '+272', '+243', '+1960', '+1995', '+1927',
#        '+2405', '+2396', '+1958', '+1962', '+66'], dtype=object)

# %%
df[df['carbon_emission% num'] == '0']['Carbon emissions estimate'].min()
# Out:
# 333

# %%
df[df['carbon_emission% num'] == '0']['Carbon emissions estimate'].max()
# Out:
# 379

# %%
df.loc[df['carbon_emission% num'].str.contains('-'), 'carbon_emission% num symbol'] = '-'
df.loc[df['carbon_emission% num'].str.contains('\+'), 'carbon_emission% num symbol'] = '+'

# %%
df['carbon_emission% num symbol'].unique()
# Out:
# array(['-', '+', nan], dtype=object)

# %%
df['carbon_emission% num'] = df['carbon_emission% num'].str.replace('-','')
df['carbon_emission% num'] = df['carbon_emission% num'].str.replace('+','')

# %%
df['carbon_emission% num'].unique()
# Out:
# array(['18', '24', '19', '6', '12', '31', '14', '13', '0', '29', '55',
#        '40', '17', '23', '9', '16', '53', '26', '30', '7', '21', '10',
#        '49', '27', '20', '28', '1948', '50', '22', '41', '8', '1955',
#        '1917', '11', '25', '2351', '15', '33', '48', '1952', '32', '51',
#        '132', '1923', '47', '133', '45', '2394', '', '39', '1904', '93',
#        '81', '85', '97', '37', '1922', '124', '1957', '59', '70', '129',
#        '43', '52', '46', '54', '131', '2356', '91', '35', '92', '205',
#        '250', '34', '130', '79', '74', '1909', '1956', '56', '69', '174',
#        '99', '38', '1949', '1898', '1911', '1918', '2382', '1942', '1950',
#        '98', '1916', '90', '166', '1947', '2387', '102', '1931', '1935',
#        '2368', '2330', '1900', '1887', '127', '1905', '1938', '1906',
#        '1939', '2344', '128', '62', '2389', '75', '61', '83', '1930',
#        '84', '89', '87', '42', '80', '2349', '2398', '2401', '88', '1989',
#        '1991', '123', '1966', '1928', '1934', '1959', '36', '2403',
#        '2408', '1915', '1920', '94', '2371', '44', '1965', '1973', '2410',
#        '1940', '2422', '1972', '2419', '2377', '1921', '1926', '2415',
#        '2364', '1925', '1953', '272', '243', '1960', '1995', '1927',
#        '2405', '2396', '1958', '1962', '66'], dtype=object)

# %%
df['carbon_emission% num'] = pd.to_numeric(df['carbon_emission% num'], errors='coerce').astype('Int64')
df['carbon_emission% num'].unique()
# Out:
# <IntegerArray>
# [  18,   24,   19,    6,   12,   31,   14,   13,    0,   29,
#  ...
#   272,  243, 1960, 1995, 1927, 2405, 2396, 1958, 1962,   66]
# Length: 165, dtype: Int64

# %%
df.loc[df['carbon_emission% num symbol'] == '+', 'carbon_emission% num'] = df['carbon_emission% num'] + 100
df.loc[df['carbon_emission% num symbol'] == '-', 'carbon_emission% num'] = 100 - df['carbon_emission% num']
df.loc[df['carbon_emission% num'] == 0, 'carbon_emission% num'] = 100

# %%
df['carbon_emission% num'].unique()
# Out:
# <IntegerArray>
# [  82,   76,  118,  119,   94,   88,   69,  114,  113,  100,
#  ...
#   372,  343, 2060, 2095, 2027, 2505, 2496, 2058, 2062,  166]
# Length: 196, dtype: Int64

# %%
df[df['carbon_emission% num']<300]['carbon_emission% num'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# #### Observation
# - Most flights have 20% more emission than normal
# - Other most flights have 20% less emission than normal

# %% [markdown]
# ## 11.Overhead bin

# %%
df.overhead_bin.value_counts()
# Out:
# overhead_bin
# This price for this flight doesn't include overhead bin access. If you need a carry-on bag, use the Bags filter to update prices.$254    1520
# This price for this flight doesn't include overhead bin access. If you need a carry-on bag, use the Bags filter to update prices.$204    1466
# $274                                                                                                                                     1377
# $244                                                                                                                                     1370
# $319                                                                                                                                     1178
#                                                                                                                                          ...
# $2,415                                                                                                                                      1
# $650                                                                                                                                        1
# $1,577                                                                                                                                      1
# $948                                                                                                                                        1
# $1,005                                                                                                                                      1
# Name: count, Length: 1720, dtype: int64

# %%
df.loc[df['overhead_bin'].str.contains("doesn't include overhead bin access"), 'overhead_bin'] = 'Additional charge for overhead bin'
df.loc[df['overhead_bin'].str.startswith("$"), 'overhead_bin'] = 'No additional charge for overhead bin'

# %%
df.overhead_bin.value_counts()
# Out:
# overhead_bin
# Additional charge for overhead bin       72542
# No additional charge for overhead bin    62705
# Name: count, dtype: int64

# %% [markdown]
# ### Observation
# - Comparatively more flights have additional charge for carry on bag
# - However, there are equally good amount of flight that have no additional charge for carry on bags

# %% [markdown]
# ## 12.Layover

# %% [markdown]
# ### 12.1 Layover count (New Column)

# %%
df.loc[df['layover'].str.contains("(1 of 3)", na=False), 'layover_count'] = 3
df.loc[df['layover'].str.contains("(1 of 2)", na=False), 'layover_count'] = 2
df.loc[df['layover'].str.contains("(1 of 1)", na=False), 'layover_count'] = 1
df['layover_count'] = df['layover_count'].fillna(0)
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1481990700.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['layover'].str.contains("(1 of 3)", na=False), 'layover_count'] = 3
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1481990700.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['layover'].str.contains("(1 of 2)", na=False), 'layover_count'] = 2
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1481990700.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['layover'].str.contains("(1 of 1)", na=False), 'layover_count'] = 1

# %%
df.layover_count.value_counts()
# Out:
# layover_count
# 0.0    116876
# 1.0     16369
# 2.0      1869
# 3.0       133
# Name: count, dtype: int64

# %% [markdown]
# #### Observation
# - Most of the flight do not have any layovers.

# %% [markdown]
# ## 13.Details

# %% [markdown]
# ## 14.Trip Duration

# %% [markdown]
# ### 14.1Trip Type (New Column)

# %%
df.loc[df.round_trip_duration == 0, 'Trip_Type'] = 'One Way'
df.loc[df.round_trip_duration > 0, 'Trip_Type'] = 'Rounds Trip'

# %%
df.Trip_Type.value_counts()
# Out:
# Trip_Type
# Rounds Trip    74255
# One Way        60992
# Name: count, dtype: int64

# %% [markdown]
# #### Observation
# - There are approximately equal number of trip types

# %% [markdown]
# # Source Dataframe

# %%
# saving primary DataFrame as source_df_details that can be referred back as and when needed. 

source_df_details = df

# %%
df = source_df_details

# %%
df.columns
# Out:
# Index(['index', 'Report_Run_Time', 'carrier', 'from_loc', 'to_loc', 'stop',
#        'price', 'from_timestamp', 'to_timestamp', 'from_date', 'to_date',
#        'carbon_emission', 'overhead_bin', 'layover', 'details',
#        'round_trip_duration', 'Airport_Route', 'From_City', 'To_City',
#        'City_Route', 'from_hour', 'from_hour_segment', 'to_hour',
#        'to_hour_segment', 'Holiday', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'flight_duration', 'Fly_WeekDay',
#        'flight_duration_value', 'carbon_array', 'Carbon emissions estimate',
#        'carbon_emission_1', 'carbon_emission%',
#        'Carbon emissions estimate num', 'carbon_emission% num',
#        'carbon_emission% num symbol', 'layover_count', 'Trip_Type'],
#       dtype='object')

# %%
df = df[['Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route',
       'City_Route', 'stop', 'price','overhead_bin', 'layover_count', 'round_trip_duration',
       'Carbon emissions estimate num', 'carbon_emission% num','Days_to_Fly',
       'from_timestamp_1', 'to_timestamp_1', 'from_hour_segment', 'to_hour_segment','flight_duration_value','Holiday','Fly_WeekDay']]

# %%
df[df.duplicated()].shape
df = df.drop_duplicates(keep='first')

# %%
df.head(2)
# Out:
#   Report_Run_Time carrier    Trip_Type Airport_Route  \
# 0      2024-03-10  Spirit  Rounds Trip     EWR - LAX
# 1      2024-03-10  Alaska  Rounds Trip     EWR - LAX
#
#                     City_Route     stop  price  \
# 0  New York City - Los Angeles  Nonstop  211.0
# 1  New York City - Los Angeles  Nonstop  297.0
#
#                             overhead_bin  layover_count  round_trip_duration  \
# 0     Additional charge for overhead bin            0.0                   89
# 1  No additional charge for overhead bin            0.0                   89
#
#    Carbon emissions estimate num  carbon_emission% num  Days_to_Fly  \
# 0                            293                    82           18
# 1                            272                    76           18
#
#      from_timestamp_1      to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0 2024-03-28 06:47:00 2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1 2024-03-28 07:30:00 2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
#
#    flight_duration_value      Holiday  Fly_WeekDay
# 0                    6.5  Not_Holiday            4
# 1                    6.3  Not_Holiday            4

# %% [markdown]
# # EDA - Multivariate Analysis

# %% [markdown]
# #### Observation
# - price is target variable, so let perform multivariate EDA using price as primary data point

# %%
# price vs carrier
# price vs trip_type
# price vs airport route
# price vs city route
# price vs stop
# price vs layover count
# price vs round trip duration
# price vs Carbon emissions estimate num
# price vs carbon_emission% num
# price vs Days_to_Fly
# price vs from_hour_segment
# price vs to_hour_segment
# price vs flight_duration_value

# %% [markdown]
# ## Price vs Carrier

# %% [markdown]
# ### Price vs carrier vs city route

# %%
plt.figure(figsize=(25, 8))

plt.subplot(1,2,1)
carrier_counts = df['carrier'].value_counts()
ordered_carriers = carrier_counts.index

ax = sns.barplot(x=df['carrier'], y=df['price'], hue=df['City_Route'], order=ordered_carriers, estimator=np.median)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# plt.show()

plt.subplot(1,2,2)
bx = sns.boxplot(x=df['carrier'], y=df['price'], hue=df['City_Route'],order=ordered_carriers)
bx.set_xticklabels(bx.get_xticklabels(), rotation=90)
plt.show()

plt.tight_layout()
plt.show()

# %%
pivot_table_mean = pd.pivot_table(df,index='carrier',columns='City_Route',values='price',aggfunc='mean')
pivot_table_mean
# Out:
# City_Route            Los Angeles - New York City  New York City - Los Angeles
# carrier
# Alaska                                 338.490003                   320.229455
# American                               428.366547                   398.339497
# Delta                                  435.941352                   397.827763
# Frontier                               189.627756                   205.591071
# JetBlue                                361.883632                   333.232171
# Spirit                                 211.458960                   202.888941
# Sun Country Airlines                   229.603015                   243.127273
# Third Party                            235.243383                   217.255017
# United                                 347.784353                   329.398382

# %%
sns.heatmap(pivot_table_mean, annot=True, fmt=".0f")
# Out:
# <Axes: xlabel='City_Route', ylabel='carrier'>

# %%
from scipy.stats import mode
from collections import Counter


def mode_func(x):
    if len(x) > 0:
        counts = Counter(x)
        mode = max(counts, key=counts.get)
        return mode
    else:
        return None

# Create the pivot table with the custom function as aggfunc
pivot_table_mode = pd.pivot_table(df, index='carrier', columns='City_Route', values='price', aggfunc=mode_func)

# Display the pivot table
pivot_table_mode
# Out:
# City_Route            Los Angeles - New York City  New York City - Los Angeles
# carrier
# Alaska                                      259.0                        219.0
# American                                    244.0                        244.0
# Delta                                       274.0                        274.0
# Frontier                                    119.0                         96.0
# JetBlue                                     254.0                        204.0
# Spirit                                       96.0                         96.0
# Sun Country Airlines                        183.0                        253.0
# Third Party                                  99.0                         96.0
# United                                      160.0                        124.0

# %%
sns.heatmap(pivot_table_mode, annot=True, fmt=".0f")
# Out:
# <Axes: xlabel='City_Route', ylabel='carrier'>

# %% [markdown]
# #### Observation
# - American and Delta seems to have higher price than other carriers.
# - Looking at the box plot American airlines seems to have most number of outliers. (May be the due to these variations average price is higher, however after checking mode value, point 1 seems to be a valid observation.)

# %% [markdown]
# ### Price vs carrier vs trip_type

# %%
sns.barplot(x = df['carrier'], y = df['price'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='carrier', ylabel='price'>

# %%
df_sorted = df[df['Trip_Type'] == 'One Way'].groupby('carrier')['price'].mean().sort_values().index
sns.barplot(x='carrier', y='price', hue='Trip_Type', data=df, order=df_sorted)
# Out:
# <Axes: xlabel='carrier', ylabel='price'>

# %% [markdown]
# #### Observation
# - Carrier that have higher mean price for one way have higher mean price for round trip

# %% [markdown]
# ### Price vs carrier vs trip_type

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = df['carrier'], y = df['price'], hue=df['from_hour_segment'])
plt.legend(bbox_to_anchor=(1.05, 1))

# %%
plt.figure(figsize=(12,5))
sns.barplot(x = df[df['price'] < 500]['carrier'], y = df[df['price'] < 500]['price'], hue=df[df['price'] < 500]['from_hour_segment'])
plt.legend(bbox_to_anchor=(1.05, 1))

# %% [markdown]
# #### Observation
# - Jet Blue seems to have consistent avg price for different fly hour segment of start time compared to others.
# - For 3-6 AM Jet Blue seems to have relatively higher price whereas other carriers seems to have relatively lower price compared their hour segment.

# %% [markdown]
# ## price vs trip_type

# %%
sns.barplot(x=df['Trip_Type'], y=df['price'])
# Out:
# <Axes: xlabel='Trip_Type', ylabel='price'>

# %% [markdown]
# ### price vs trip type vs carrier

# %%
sns.barplot(x=df['Trip_Type'], y=df['price'], hue=df['carrier'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# ## price vs airport route

# %%
sns.barplot(x = df['Airport_Route'], y = df['price'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='Airport_Route', ylabel='price'>

# %% [markdown]
# ### price vs airport route vs city route

# %%
sns.barplot(x = df['Airport_Route'], y = df['price'], hue=df['City_Route'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# #### Observation
# - route to and from LGA seems to have lower price
# - LGA, EWR, JFK seems to be lower to higher route by average price

# %%
sns.barplot(x = df['Airport_Route'], y = df['price'], hue=df['Trip_Type'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# ## price vs city route

# %%
sns.barplot(x = df['City_Route'], y = df['price'])
# Out:
# <Axes: xlabel='City_Route', ylabel='price'>

# %% [markdown]
# ## price vs stop

# %%
# stop and layover count are same. skipping stop feature EDA

# %% [markdown]
# ## price vs layover count

# %%
sns.barplot(x = df['layover_count'], y = df['price'])
# Out:
# <Axes: xlabel='layover_count', ylabel='price'>

# %% [markdown]
# ### Observation
# - Non stop flights have higher price compared to flights with layover

# %% [markdown]
# ### price vs layover vs carrier

# %%
sns.barplot(x = df['layover_count'], y = df['price'], hue=df['carrier'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# ### price vs layover vs trip_type

# %%
sns.barplot(x = df['layover_count'], y = df['price'], hue= df['Trip_Type'])
# Out:
# <Axes: xlabel='layover_count', ylabel='price'>

# %% [markdown]
# ## price vs round trip duration

# %%
plt.figure(figsize=(25, 8))
sns.barplot(y = df['price'], x = df['round_trip_duration'])
# Out:
# <Axes: xlabel='round_trip_duration', ylabel='price'>

# %% [markdown]
# ### Observation
# - There seems to be no clear trend for round trip duration, meaning if the day b/w inbound flight and outbound flight seems to have no impact on price.
# - However, later let's evaluate this in correlation matrix b/w price and round trip duration

# %% [markdown]
# ## price vs Carbon emissions estimate num

# %%
df.columns
# Out:
# Index(['Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route',
#        'City_Route', 'stop', 'price', 'overhead_bin', 'layover_count',
#        'round_trip_duration', 'Carbon emissions estimate num',
#        'carbon_emission% num', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'from_hour_segment', 'to_hour_segment',
#        'flight_duration_value', 'Holiday', 'Fly_WeekDay'],
#       dtype='object')

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(x = df['price'], y = df['Carbon emissions estimate num'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='price', ylabel='Carbon emissions estimate num'>

# %% [markdown]
# ### Observation
# - Carbon emission is lower for one way
# - There is more variation in carbon emission in round trip duration as compared to one way

# %% [markdown]
# ## price vs carbon_emission% num

# %%
sns.scatterplot(x = df['price'], y = df['carbon_emission% num'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='price', ylabel='carbon_emission% num'>

# %% [markdown]
# ## price vs Days_to_Fly

# %%
plt.figure(figsize=(25, 8))
ax = sns.barplot(x=df['Days_to_Fly'], y=df['price'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)  # Rotate x-axis labels by 90 degrees
plt.show()

# %% [markdown]
# ### Observation
# - If we divide 90 days in 3 sections, 2nd section seems to have lower prices.
# - It can mean that booking a flight b/w 30 - 60 days has lower price as compared to 60 - 90 days
# - If flights are booked within a week a flying, the price are highest inversely proportional in order of days left to fly

# %% [markdown]
# ### price vs days to fly vs trip type

# %%
plt.figure(figsize=(25, 8))
ax = sns.barplot(x=df['Days_to_Fly'], y=df['price'], hue=df['Trip_Type'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
sns.scatterplot(x=df['Days_to_Fly'], y=df['price'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='Days_to_Fly', ylabel='price'>

# %% [markdown]
# ### price vs from_hour_segment

# %%
plt.figure(figsize=(25, 8))
ax = sns.barplot(x = df['Trip_Type'], y = df['price'], hue=df['from_hour_segment'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %%
df['from_hour_segment'].unique()
# Out:
# array(['3. 6 AM - 9 AM', '2. 3 AM - 6 AM', '5. 12 PM - 3 PM',
#        '6. 3 PM - 6 PM', '8. 9 PM - 12 AM', '7. 6 PM - 9 PM',
#        '4. 9 AM - 12 PM', '1. 12 AM - 3 AM'], dtype=object)

# %%
plt.figure(figsize=(25, 8))
ax = sns.barplot(x = df['City_Route'], y = df['price'], hue=df['from_hour_segment'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# ## price vs to_hour_segment

# %% [markdown]
# ### price vs flight_duration_value

# %%
sns.scatterplot(x = df['price'],y = df['flight_duration_value'])
# Out:
# <Axes: xlabel='price', ylabel='flight_duration_value'>

# %% [markdown]
# ### Price vs flight duration value vs city route

# %%
sns.scatterplot(x = df['price'],y = df['flight_duration_value'], hue=df['City_Route'])
# Out:
# <Axes: xlabel='price', ylabel='flight_duration_value'>

# %% [markdown]
# #### Observation
# - There is more variation in price of flight b/w 5-8 hours flight duration

# %% [markdown]
# ### Price vs flight duration value vs trip type

# %%
sns.scatterplot(x = df['price'],y = df['flight_duration_value'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='price', ylabel='flight_duration_value'>

# %% [markdown]
# #### Observation
# - There is more variation in price of flight b/w 5-8 hours for round trip duration compared to one way.

# %%
sns.scatterplot(x = df[df['price']<500]['price'],y = df['flight_duration_value'], hue=df['City_Route'], style=df['Trip_Type'])
# Out:
# <Axes: xlabel='price', ylabel='flight_duration_value'>

# %% [markdown]
# ## Price vs days to fly vs trip type

# %%
sns.scatterplot(x = df[df['price']<1000]['price'],y = df['Days_to_Fly'], hue=df['Trip_Type'])
# Out:
# <Axes: xlabel='price', ylabel='Days_to_Fly'>

# %%
df['Holiday'].unique()
# Out:
# array(['Not_Holiday', 'Holiday'], dtype=object)

# %%
sns.barplot(x=df['Holiday'], y=df['price'])
# Out:
# <Axes: xlabel='Holiday', ylabel='price'>

# %% [markdown]
# #### Observation
# - Price is more for flight booked during holidays

# %%
sns.barplot(x=df['Fly_WeekDay'], y=df['price'])
# Out:
# <Axes: xlabel='Fly_WeekDay', ylabel='price'>

# %% [markdown]
# #### Observation
# - Avg price seems to be higher for weekdays in following order (Sun, Mon, Sat, Thus, Fri, Web, Tues)

# %%
sns.barplot(x=df['Fly_WeekDay'], y=df['price'], hue=df['Holiday'])
# Out:
# <Axes: xlabel='Fly_WeekDay', ylabel='price'>

# %% [markdown]
# # EDA - Pandas Profiling or Detail Library

# %%
# import dtale
# dtale.show(df)

# %%
df.columns
# Out:
# Index(['Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route',
#        'City_Route', 'stop', 'price', 'overhead_bin', 'layover_count',
#        'round_trip_duration', 'Carbon emissions estimate num',
#        'carbon_emission% num', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'from_hour_segment', 'to_hour_segment',
#        'flight_duration_value', 'Holiday', 'Fly_WeekDay'],
#       dtype='object')

# %%
df = df[['Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route',
         'price', 'overhead_bin','layover_count',
       'round_trip_duration', 'Carbon emissions estimate num',
       'carbon_emission% num', 'Days_to_Fly', 'from_timestamp_1',
       'to_timestamp_1', 'from_hour_segment', 'to_hour_segment',
       'flight_duration_value','Holiday','Fly_WeekDay']]

# %%
df['Report_Run_Time'] = pd.to_datetime(df['Report_Run_Time'])

# %%
# profile = ProfileReport(df)
# profile.to_file(r"C:\Users\anshu\Desktop\Anshul Data Science\Flight_Data\flight_df_profile_report.html")

# %%
df.head()
# Out:
#   Report_Run_Time  carrier    Trip_Type Airport_Route  price  \
# 0      2024-03-10   Spirit  Rounds Trip     EWR - LAX  211.0
# 1      2024-03-10   Alaska  Rounds Trip     EWR - LAX  297.0
# 2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX  298.0
# 3      2024-03-10   United  Rounds Trip     EWR - LAX  302.0
# 4      2024-03-10   Spirit  Rounds Trip     LGA - LAX  269.0
#
#                             overhead_bin  layover_count  round_trip_duration  \
# 0     Additional charge for overhead bin            0.0                   89
# 1  No additional charge for overhead bin            0.0                   89
# 2     Additional charge for overhead bin            0.0                   89
# 3     Additional charge for overhead bin            0.0                   89
# 4  No additional charge for overhead bin            1.0                   89
#
#    Carbon emissions estimate num  carbon_emission% num  Days_to_Fly  \
# 0                            293                    82           18
# 1                            272                    76           18
# 2                            422                   118           18
# 3                            427                   119           18
# 4                            338                    94           18
#
#      from_timestamp_1      to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0 2024-03-28 06:47:00 2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1 2024-03-28 07:30:00 2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 2 2024-03-28 05:15:00 2024-03-28 08:30:00    2. 3 AM - 6 AM   3. 6 AM - 9 AM
# 3 2024-03-28 12:00:00 2024-03-28 15:24:00   5. 12 PM - 3 PM   6. 3 PM - 6 PM
# 4 2024-03-28 16:29:00 2024-03-28 17:00:00    6. 3 PM - 6 PM   6. 3 PM - 6 PM
#
#    flight_duration_value      Holiday  Fly_WeekDay
# 0                    6.5  Not_Holiday            4
# 1                    6.3  Not_Holiday            4
# 2                    6.2  Not_Holiday            4
# 3                    6.4  Not_Holiday            4
# 4                   27.5  Not_Holiday            4

# %% [markdown]
# # Missing Value Imputation

# %%
df.isnull().sum()
# Out:
# Report_Run_Time                    0
# carrier                            0
# Trip_Type                          0
# Airport_Route                      0
# price                              0
# overhead_bin                       0
# layover_count                      0
# round_trip_duration                0
# Carbon emissions estimate num    642
# carbon_emission% num              62
# Days_to_Fly                        0
# from_timestamp_1                   0
# to_timestamp_1                     0
# from_hour_segment                  0
# to_hour_segment                    0
# flight_duration_value              0
# Holiday                            0
# Fly_WeekDay                        0
# dtype: int64

# %%
sns.scatterplot(x = df['Carbon emissions estimate num'], y=df['carbon_emission% num'])
# Out:
# <Axes: xlabel='Carbon emissions estimate num', ylabel='carbon_emission% num'>

# %%
train_carbon_df = df[~(df['Carbon emissions estimate num'].isnull()) & ~(df['carbon_emission% num'].isnull())][['Carbon emissions estimate num','carbon_emission% num']]
train_carbon_df
# Out:
#         Carbon emissions estimate num  carbon_emission% num
# 0                                 293                    82
# 1                                 272                    76
# 2                                 422                   118
# 3                                 427                   119
# 4                                 338                    94
# ...                               ...                   ...
# 135242                            300                    85
# 135243                            370                   100
# 135244                            298                    85
# 135245                            298                    85
# 135246                            298                    85
#
# [134572 rows x 2 columns]

# %%
test_carbon_df = df[(df['Carbon emissions estimate num'].isnull()) & ~(df['carbon_emission% num'].isnull())][['Carbon emissions estimate num','carbon_emission% num']]
test_carbon_df = test_carbon_df.reset_index()
test_carbon_df
# Out:
#       index  Carbon emissions estimate num  carbon_emission% num
# 0       194                           <NA>                  2048
# 1       472                           <NA>                  2055
# 2       517                           <NA>                  2017
# 3       571                           <NA>                  2048
# 4       663                           <NA>                  2017
# ..      ...                            ...                   ...
# 575  133515                           <NA>                  2048
# 576  133657                           <NA>                  2004
# 577  133661                           <NA>                  2009
# 578  133755                           <NA>                  2048
# 579  133802                           <NA>                  2048
#
# [580 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_carbon_df[['carbon_emission% num']],train_carbon_df[['Carbon emissions estimate num']])
# Out:
# LinearRegression()

# %%
carbon_y_pred = model.predict(test_carbon_df[['carbon_emission% num']])
carbon_y_pred
# Out:
# array([[7305.25200573],
#        [7330.22289681],
#        [7194.66663095],
#        [7305.25200573],
#        [7194.66663095],
#        [8742.8618778 ],
#        [7319.52108634],
#        [7194.66663095],
#        [7194.66663095],
#        [7194.66663095],
#        [7330.22289681],
#        [7305.25200573],
#        [7216.07025188],
#        [7194.66663095],
#        [7305.25200573],
#        [7319.52108634],
#        [7194.66663095],
#        [7194.66663095],
#        [7216.07025188],
#        [7194.66663095],
#        [7212.50298172],
#        [8878.41814365],
#        [7194.66663095],
#        [8910.52357504],
#        [7305.25200573],
#        [7330.22289681],
#        [7305.25200573],
#        [7148.29211895],
#        [7166.12846972],
#        [7305.25200573],
#        [7305.25200573]])

# %%
carbon_y_pred = pd.DataFrame(carbon_y_pred, columns=['Carbon emissions estimate num pred'])
carbon_y_pred = round(carbon_y_pred)
carbon_y_pred
# Out:
#      Carbon emissions estimate num pred
# 0                                7305.0
# 1                                7330.0
# 2                                7195.0
# 3                                7305.0
# 4                                7195.0
# ..                                  ...
# 575                              7305.0
# 576                              7148.0
# 577                              7166.0
# 578                              7305.0
# 579                              7305.0
#
# [580 rows x 1 columns]

# %%
carbon_df = pd.concat([test_carbon_df,carbon_y_pred], axis=1)
carbon_df.columns
# Out:
# Index(['index', 'Carbon emissions estimate num', 'carbon_emission% num',
#        'Carbon emissions estimate num pred'],
#       dtype='object')

# %%
carbon_df = carbon_df[['index', 'carbon_emission% num',
       'Carbon emissions estimate num pred']]
carbon_df
# Out:
#       index  carbon_emission% num  Carbon emissions estimate num pred
# 0       194                  2048                              7305.0
# 1       472                  2055                              7330.0
# 2       517                  2017                              7195.0
# 3       571                  2048                              7305.0
# 4       663                  2017                              7195.0
# ..      ...                   ...                                 ...
# 575  133515                  2048                              7305.0
# 576  133657                  2004                              7148.0
# 577  133661                  2009                              7166.0
# 578  133755                  2048                              7305.0
# 579  133802                  2048                              7305.0
#
# [580 rows x 3 columns]

# %%
df = df.reset_index()
df
# Out:
#          index Report_Run_Time  carrier    Trip_Type Airport_Route  price  \
# 0            0      2024-03-10   Spirit  Rounds Trip     EWR - LAX  211.0
# 1            1      2024-03-10   Alaska  Rounds Trip     EWR - LAX  297.0
# 2            2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX  298.0
# 3            3      2024-03-10   United  Rounds Trip     EWR - LAX  302.0
# 4            4      2024-03-10   Spirit  Rounds Trip     LGA - LAX  269.0
# ...        ...             ...      ...          ...           ...    ...
# 135209  135242      2024-04-06   Alaska      One Way     LAX - EWR  259.0
# 135210  135243      2024-04-06  JetBlue      One Way     LAX - EWR  259.0
# 135211  135244      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135212  135245      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135213  135246      2024-04-06    Delta      One Way     LAX - JFK  274.0
#
#                                  overhead_bin  layover_count  \
# 0          Additional charge for overhead bin            0.0
# 1       No additional charge for overhead bin            0.0
# 2          Additional charge for overhead bin            0.0
# 3          Additional charge for overhead bin            0.0
# 4       No additional charge for overhead bin            1.0
# ...                                       ...            ...
# 135209  No additional charge for overhead bin            0.0
# 135210     Additional charge for overhead bin            0.0
# 135211  No additional charge for overhead bin            0.0
# 135212  No additional charge for overhead bin            0.0
# 135213  No additional charge for overhead bin            0.0
#
#         round_trip_duration  Carbon emissions estimate num  \
# 0                        89                            293
# 1                        89                            272
# 2                        89                            422
# 3                        89                            427
# 4                        89                            338
# ...                     ...                            ...
# 135209                    0                            300
# 135210                    0                            370
# 135211                    0                            298
# 135212                    0                            298
# 135213                    0                            298
#
#         carbon_emission% num  Days_to_Fly    from_timestamp_1  \
# 0                         82           18 2024-03-28 06:47:00
# 1                         76           18 2024-03-28 07:30:00
# 2                        118           18 2024-03-28 05:15:00
# 3                        119           18 2024-03-28 12:00:00
# 4                         94           18 2024-03-28 16:29:00
# ...                      ...          ...                 ...
# 135209                    85           89 2024-07-04 10:20:00
# 135210                   100           89 2024-07-04 11:20:00
# 135211                    85           89 2024-07-04 06:00:00
# 135212                    85           89 2024-07-04 09:20:00
# 135213                    85           89 2024-07-04 16:00:00
#
#             to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0      2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1      2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 2      2024-03-28 08:30:00    2. 3 AM - 6 AM   3. 6 AM - 9 AM
# 3      2024-03-28 15:24:00   5. 12 PM - 3 PM   6. 3 PM - 6 PM
# 4      2024-03-28 17:00:00    6. 3 PM - 6 PM   6. 3 PM - 6 PM
# ...                    ...               ...              ...
# 135209 2024-07-05 18:59:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135210 2024-07-05 19:49:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135211 2024-07-05 14:35:00    3. 6 AM - 9 AM  5. 12 PM - 3 PM
# 135212 2024-07-05 18:15:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135213 2024-07-05 00:37:00    6. 3 PM - 6 PM  1. 12 AM - 3 AM
#
#         flight_duration_value      Holiday  Fly_WeekDay
# 0                         6.5  Not_Holiday            4
# 1                         6.3  Not_Holiday            4
# 2                         6.2  Not_Holiday            4
# 3                         6.4  Not_Holiday            4
# 4                        27.5  Not_Holiday            4
# ...                       ...          ...          ...
# 135209                    5.6      Holiday            4
# 135210                    5.5      Holiday            4
# 135211                    5.6      Holiday            4
# 135212                    5.9      Holiday            4
# 135213                    5.6      Holiday            4
#
# [135214 rows x 19 columns]

# %%
df = pd.merge(df, carbon_df[['index', 'Carbon emissions estimate num pred']], on= 'index', how='left')
df
# Out:
#          index Report_Run_Time  carrier    Trip_Type Airport_Route  price  \
# 0            0      2024-03-10   Spirit  Rounds Trip     EWR - LAX  211.0
# 1            1      2024-03-10   Alaska  Rounds Trip     EWR - LAX  297.0
# 2            2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX  298.0
# 3            3      2024-03-10   United  Rounds Trip     EWR - LAX  302.0
# 4            4      2024-03-10   Spirit  Rounds Trip     LGA - LAX  269.0
# ...        ...             ...      ...          ...           ...    ...
# 135209  135242      2024-04-06   Alaska      One Way     LAX - EWR  259.0
# 135210  135243      2024-04-06  JetBlue      One Way     LAX - EWR  259.0
# 135211  135244      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135212  135245      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135213  135246      2024-04-06    Delta      One Way     LAX - JFK  274.0
#
#                                  overhead_bin  layover_count  \
# 0          Additional charge for overhead bin            0.0
# 1       No additional charge for overhead bin            0.0
# 2          Additional charge for overhead bin            0.0
# 3          Additional charge for overhead bin            0.0
# 4       No additional charge for overhead bin            1.0
# ...                                       ...            ...
# 135209  No additional charge for overhead bin            0.0
# 135210     Additional charge for overhead bin            0.0
# 135211  No additional charge for overhead bin            0.0
# 135212  No additional charge for overhead bin            0.0
# 135213  No additional charge for overhead bin            0.0
#
#         round_trip_duration  Carbon emissions estimate num  \
# 0                        89                            293
# 1                        89                            272
# 2                        89                            422
# 3                        89                            427
# 4                        89                            338
# ...                     ...                            ...
# 135209                    0                            300
# 135210                    0                            370
# 135211                    0                            298
# 135212                    0                            298
# 135213                    0                            298
#
#         carbon_emission% num  Days_to_Fly    from_timestamp_1  \
# 0                         82           18 2024-03-28 06:47:00
# 1                         76           18 2024-03-28 07:30:00
# 2                        118           18 2024-03-28 05:15:00
# 3                        119           18 2024-03-28 12:00:00
# 4                         94           18 2024-03-28 16:29:00
# ...                      ...          ...                 ...
# 135209                    85           89 2024-07-04 10:20:00
# 135210                   100           89 2024-07-04 11:20:00
# 135211                    85           89 2024-07-04 06:00:00
# 135212                    85           89 2024-07-04 09:20:00
# 135213                    85           89 2024-07-04 16:00:00
#
#             to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0      2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1      2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 2      2024-03-28 08:30:00    2. 3 AM - 6 AM   3. 6 AM - 9 AM
# 3      2024-03-28 15:24:00   5. 12 PM - 3 PM   6. 3 PM - 6 PM
# 4      2024-03-28 17:00:00    6. 3 PM - 6 PM   6. 3 PM - 6 PM
# ...                    ...               ...              ...
# 135209 2024-07-05 18:59:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135210 2024-07-05 19:49:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135211 2024-07-05 14:35:00    3. 6 AM - 9 AM  5. 12 PM - 3 PM
# 135212 2024-07-05 18:15:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135213 2024-07-05 00:37:00    6. 3 PM - 6 PM  1. 12 AM - 3 AM
#
#         flight_duration_value      Holiday  Fly_WeekDay  \
# 0                         6.5  Not_Holiday            4
# 1                         6.3  Not_Holiday            4
# 2                         6.2  Not_Holiday            4
# 3                         6.4  Not_Holiday            4
# 4                        27.5  Not_Holiday            4
# ...                       ...          ...          ...
# 135209                    5.6      Holiday            4
# 135210                    5.5      Holiday            4
# 135211                    5.6      Holiday            4
# 135212                    5.9      Holiday            4
# 135213                    5.6      Holiday            4
#
#         Carbon emissions estimate num pred
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 135209                                 NaN
# 135210                                 NaN
# 135211                                 NaN
# 135212                                 NaN
# 135213                                 NaN
#
# [135214 rows x 20 columns]

# %%
df.loc[df['Carbon emissions estimate num'].isnull(), 'Carbon emissions estimate num'] = df['Carbon emissions estimate num pred']
df
# Out:
#          index Report_Run_Time  carrier    Trip_Type Airport_Route  price  \
# 0            0      2024-03-10   Spirit  Rounds Trip     EWR - LAX  211.0
# 1            1      2024-03-10   Alaska  Rounds Trip     EWR - LAX  297.0
# 2            2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX  298.0
# 3            3      2024-03-10   United  Rounds Trip     EWR - LAX  302.0
# 4            4      2024-03-10   Spirit  Rounds Trip     LGA - LAX  269.0
# ...        ...             ...      ...          ...           ...    ...
# 135209  135242      2024-04-06   Alaska      One Way     LAX - EWR  259.0
# 135210  135243      2024-04-06  JetBlue      One Way     LAX - EWR  259.0
# 135211  135244      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135212  135245      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135213  135246      2024-04-06    Delta      One Way     LAX - JFK  274.0
#
#                                  overhead_bin  layover_count  \
# 0          Additional charge for overhead bin            0.0
# 1       No additional charge for overhead bin            0.0
# 2          Additional charge for overhead bin            0.0
# 3          Additional charge for overhead bin            0.0
# 4       No additional charge for overhead bin            1.0
# ...                                       ...            ...
# 135209  No additional charge for overhead bin            0.0
# 135210     Additional charge for overhead bin            0.0
# 135211  No additional charge for overhead bin            0.0
# 135212  No additional charge for overhead bin            0.0
# 135213  No additional charge for overhead bin            0.0
#
#         round_trip_duration  Carbon emissions estimate num  \
# 0                        89                            293
# 1                        89                            272
# 2                        89                            422
# 3                        89                            427
# 4                        89                            338
# ...                     ...                            ...
# 135209                    0                            300
# 135210                    0                            370
# 135211                    0                            298
# 135212                    0                            298
# 135213                    0                            298
#
#         carbon_emission% num  Days_to_Fly    from_timestamp_1  \
# 0                         82           18 2024-03-28 06:47:00
# 1                         76           18 2024-03-28 07:30:00
# 2                        118           18 2024-03-28 05:15:00
# 3                        119           18 2024-03-28 12:00:00
# 4                         94           18 2024-03-28 16:29:00
# ...                      ...          ...                 ...
# 135209                    85           89 2024-07-04 10:20:00
# 135210                   100           89 2024-07-04 11:20:00
# 135211                    85           89 2024-07-04 06:00:00
# 135212                    85           89 2024-07-04 09:20:00
# 135213                    85           89 2024-07-04 16:00:00
#
#             to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0      2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1      2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 2      2024-03-28 08:30:00    2. 3 AM - 6 AM   3. 6 AM - 9 AM
# 3      2024-03-28 15:24:00   5. 12 PM - 3 PM   6. 3 PM - 6 PM
# 4      2024-03-28 17:00:00    6. 3 PM - 6 PM   6. 3 PM - 6 PM
# ...                    ...               ...              ...
# 135209 2024-07-05 18:59:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135210 2024-07-05 19:49:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135211 2024-07-05 14:35:00    3. 6 AM - 9 AM  5. 12 PM - 3 PM
# 135212 2024-07-05 18:15:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135213 2024-07-05 00:37:00    6. 3 PM - 6 PM  1. 12 AM - 3 AM
#
#         flight_duration_value      Holiday  Fly_WeekDay  \
# 0                         6.5  Not_Holiday            4
# 1                         6.3  Not_Holiday            4
# 2                         6.2  Not_Holiday            4
# 3                         6.4  Not_Holiday            4
# 4                        27.5  Not_Holiday            4
# ...                       ...          ...          ...
# 135209                    5.6      Holiday            4
# 135210                    5.5      Holiday            4
# 135211                    5.6      Holiday            4
# 135212                    5.9      Holiday            4
# 135213                    5.6      Holiday            4
#
#         Carbon emissions estimate num pred
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 135209                                 NaN
# 135210                                 NaN
# 135211                                 NaN
# 135212                                 NaN
# 135213                                 NaN
#
# [135214 rows x 20 columns]

# %%
df = df[~df['Carbon emissions estimate num'].isnull()]
df
# Out:
#          index Report_Run_Time  carrier    Trip_Type Airport_Route  price  \
# 0            0      2024-03-10   Spirit  Rounds Trip     EWR - LAX  211.0
# 1            1      2024-03-10   Alaska  Rounds Trip     EWR - LAX  297.0
# 2            2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX  298.0
# 3            3      2024-03-10   United  Rounds Trip     EWR - LAX  302.0
# 4            4      2024-03-10   Spirit  Rounds Trip     LGA - LAX  269.0
# ...        ...             ...      ...          ...           ...    ...
# 135209  135242      2024-04-06   Alaska      One Way     LAX - EWR  259.0
# 135210  135243      2024-04-06  JetBlue      One Way     LAX - EWR  259.0
# 135211  135244      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135212  135245      2024-04-06    Delta      One Way     LAX - JFK  274.0
# 135213  135246      2024-04-06    Delta      One Way     LAX - JFK  274.0
#
#                                  overhead_bin  layover_count  \
# 0          Additional charge for overhead bin            0.0
# 1       No additional charge for overhead bin            0.0
# 2          Additional charge for overhead bin            0.0
# 3          Additional charge for overhead bin            0.0
# 4       No additional charge for overhead bin            1.0
# ...                                       ...            ...
# 135209  No additional charge for overhead bin            0.0
# 135210     Additional charge for overhead bin            0.0
# 135211  No additional charge for overhead bin            0.0
# 135212  No additional charge for overhead bin            0.0
# 135213  No additional charge for overhead bin            0.0
#
#         round_trip_duration  Carbon emissions estimate num  \
# 0                        89                            293
# 1                        89                            272
# 2                        89                            422
# 3                        89                            427
# 4                        89                            338
# ...                     ...                            ...
# 135209                    0                            300
# 135210                    0                            370
# 135211                    0                            298
# 135212                    0                            298
# 135213                    0                            298
#
#         carbon_emission% num  Days_to_Fly    from_timestamp_1  \
# 0                         82           18 2024-03-28 06:47:00
# 1                         76           18 2024-03-28 07:30:00
# 2                        118           18 2024-03-28 05:15:00
# 3                        119           18 2024-03-28 12:00:00
# 4                         94           18 2024-03-28 16:29:00
# ...                      ...          ...                 ...
# 135209                    85           89 2024-07-04 10:20:00
# 135210                   100           89 2024-07-04 11:20:00
# 135211                    85           89 2024-07-04 06:00:00
# 135212                    85           89 2024-07-04 09:20:00
# 135213                    85           89 2024-07-04 16:00:00
#
#             to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0      2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1      2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 2      2024-03-28 08:30:00    2. 3 AM - 6 AM   3. 6 AM - 9 AM
# 3      2024-03-28 15:24:00   5. 12 PM - 3 PM   6. 3 PM - 6 PM
# 4      2024-03-28 17:00:00    6. 3 PM - 6 PM   6. 3 PM - 6 PM
# ...                    ...               ...              ...
# 135209 2024-07-05 18:59:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135210 2024-07-05 19:49:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135211 2024-07-05 14:35:00    3. 6 AM - 9 AM  5. 12 PM - 3 PM
# 135212 2024-07-05 18:15:00   4. 9 AM - 12 PM   7. 6 PM - 9 PM
# 135213 2024-07-05 00:37:00    6. 3 PM - 6 PM  1. 12 AM - 3 AM
#
#         flight_duration_value      Holiday  Fly_WeekDay  \
# 0                         6.5  Not_Holiday            4
# 1                         6.3  Not_Holiday            4
# 2                         6.2  Not_Holiday            4
# 3                         6.4  Not_Holiday            4
# 4                        27.5  Not_Holiday            4
# ...                       ...          ...          ...
# 135209                    5.6      Holiday            4
# 135210                    5.5      Holiday            4
# 135211                    5.6      Holiday            4
# 135212                    5.9      Holiday            4
# 135213                    5.6      Holiday            4
#
#         Carbon emissions estimate num pred
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 135209                                 NaN
# 135210                                 NaN
# 135211                                 NaN
# 135212                                 NaN
# 135213                                 NaN
#
# [135152 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# index                                      0
# Report_Run_Time                            0
# carrier                                    0
# Trip_Type                                  0
# Airport_Route                              0
# price                                      0
# overhead_bin                               0
# layover_count                              0
# round_trip_duration                        0
# Carbon emissions estimate num              0
# carbon_emission% num                       0
# Days_to_Fly                                0
# from_timestamp_1                           0
# to_timestamp_1                             0
# from_hour_segment                          0
# to_hour_segment                            0
# flight_duration_value                      0
# Holiday                                    0
# Fly_WeekDay                                0
# Carbon emissions estimate num pred    134572
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route',
#        'price', 'overhead_bin', 'layover_count', 'round_trip_duration',
#        'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly',
#        'from_timestamp_1', 'to_timestamp_1', 'from_hour_segment',
#        'to_hour_segment', 'flight_duration_value', 'Holiday', 'Fly_WeekDay',
#        'Carbon emissions estimate num pred'],
#       dtype='object')

# %%
df = df[['index', 'Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route',
       'price', 'overhead_bin', 'layover_count', 'round_trip_duration',
       'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly',
       'from_timestamp_1', 'to_timestamp_1', 'from_hour_segment',
       'to_hour_segment', 'flight_duration_value', 'Holiday', 'Fly_WeekDay']]

# %%
df.head()
# Out:
#    index Report_Run_Time  carrier    Trip_Type Airport_Route  price  \
# 0      0      2024-03-10   Spirit  Rounds Trip     EWR - LAX  211.0
# 1      1      2024-03-10   Alaska  Rounds Trip     EWR - LAX  297.0
# 2      2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX  298.0
# 3      3      2024-03-10   United  Rounds Trip     EWR - LAX  302.0
# 4      4      2024-03-10   Spirit  Rounds Trip     LGA - LAX  269.0
#
#                             overhead_bin  layover_count  round_trip_duration  \
# 0     Additional charge for overhead bin            0.0                   89
# 1  No additional charge for overhead bin            0.0                   89
# 2     Additional charge for overhead bin            0.0                   89
# 3     Additional charge for overhead bin            0.0                   89
# 4  No additional charge for overhead bin            1.0                   89
#
#    Carbon emissions estimate num  carbon_emission% num  Days_to_Fly  \
# 0                            293                    82           18
# 1                            272                    76           18
# 2                            422                   118           18
# 3                            427                   119           18
# 4                            338                    94           18
#
#      from_timestamp_1      to_timestamp_1 from_hour_segment  to_hour_segment  \
# 0 2024-03-28 06:47:00 2024-03-28 10:15:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 1 2024-03-28 07:30:00 2024-03-28 10:48:00    3. 6 AM - 9 AM  4. 9 AM - 12 PM
# 2 2024-03-28 05:15:00 2024-03-28 08:30:00    2. 3 AM - 6 AM   3. 6 AM - 9 AM
# 3 2024-03-28 12:00:00 2024-03-28 15:24:00   5. 12 PM - 3 PM   6. 3 PM - 6 PM
# 4 2024-03-28 16:29:00 2024-03-28 17:00:00    6. 3 PM - 6 PM   6. 3 PM - 6 PM
#
#    flight_duration_value      Holiday  Fly_WeekDay
# 0                    6.5  Not_Holiday            4
# 1                    6.3  Not_Holiday            4
# 2                    6.2  Not_Holiday            4
# 3                    6.4  Not_Holiday            4
# 4                   27.5  Not_Holiday            4

# %% [markdown]
# # Outlier Treatement

# %%
# sns.boxplot(df.price)

# %%
# df.price.describe()

# %%
# # Calculate the IQR for the 'price' column
# Q1 = df['price'].quantile(0.25)
# Q3 = df['price'].quantile(0.75)
# IQR = Q3 - Q1

# # Define bounds for outliers
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR

# # Identify outliers
# outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# # Displaying the number of outliers and some statistics
# num_outliers = outliers.shape[0]
# outliers_price_stats = outliers['price'].describe()

# num_outliers, outliers_price_stats

# %%
# sns.displot(df['price'], bins=50)

# %%
# df.sort_values('price', ascending=False).head(10)

# %%
# df[df['price']>1000].sort_values('price', ascending=False)['price'].hist(bins=50)

# %%
# df[df['price']>1000].sort_values('price', ascending=False).shape

# %%
# df[df['price']>1000].sort_values('price', ascending=False).shape[0]/df.sort_values('price', ascending=False).shape[0]

# %%
# df = df[df['price']<=1000]

# %%
# df.columns

# %%
# df['carrier'].value_counts()

# %%
# df['overhead_bin'].value_counts()

# %%
# df.groupby(['carrier','overhead_bin']).count()[['Report_Run_Time']]

# %%
# df[['carrier','overhead_bin','price']].groupby(['carrier','overhead_bin']).mean()[['price']]

# %%
# sns.displot(df['flight_duration_value'],bins=50)

# %%
# df[df['flight_duration_value'] < 5].tail(20).sort_values('flight_duration_value')

# %%
# sns.boxplot(df['flight_duration_value'])

# %%
# df['flight_duration_value'].describe()

# %%
# # Calculate the IQR for the 'price' column
# Q1 = df['flight_duration_value'].quantile(0.25)
# Q3 = df['flight_duration_value'].quantile(0.75)
# IQR = Q3 - Q1

# # Define bounds for outliers
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR

# # Identify outliers
# outliers = df[(df['flight_duration_value'] < lower_bound) | (df['flight_duration_value'] > upper_bound)]

# # Displaying the number of outliers and some statistics
# num_outliers = outliers.shape[0]
# outliers_price_stats = outliers['flight_duration_value'].describe()

# num_outliers, outliers_price_stats

# %% [markdown]
# # Baseline Model

# %%
baseline_df = df

# %%
baseline_df.to_csv(r'baseline_df.csv')

# %% [markdown]
# ## Columns to Encode

# %%
# baseline_df.head()

# %%
# columns_to_encode = ['carrier','Trip_Type','Airport_Route','overhead_bin','from_hour_segment','to_hour_segment', 'Holiday' ]

# %%
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()

# for columns in columns_to_encode:
#     baseline_df[columns] = label_encoder.fit_transform(baseline_df[columns])

# baseline_df

# %%
# X = baseline_df[['carrier', 'Trip_Type', 'Airport_Route'
#         , 'overhead_bin', 'layover_count', 'round_trip_duration',
#        'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly',
#      'from_hour_segment','to_hour_segment', 'flight_duration_value', 'Holiday', 'Fly_WeekDay']]

# %%
# Y = baseline_df['price']

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# from sklearn.ensemble import RandomForestRegressor
# Random_Forest_regressor = RandomForestRegressor()
# Random_Forest_regressor.fit(X_train, y_train)

# %%
# y_train_pred = Random_Forest_regressor.predict(X_train)
# y_pred = Random_Forest_regressor.predict(X_test)

# %%
# y_test

# %%
# y_pred = pd.DataFrame(y_pred)
# y_pred

# %%
# from sklearn.metrics import mean_absolute_error
# mean_absolute_error(y_test,y_pred)

# %%
# from sklearn.metrics import r2_score

# # Assuming y_test and y_pred are your actual and predicted values respectively
# r2 = r2_score(y_test, y_pred)
# print("R2 Score:", round(r2,2))

# %%
# y_test_unscaled = y_scaler.inverse_transform(y_test)
# y_test_unscaled

# %%
# y_pred_unscaled = y_scaler.inverse_transform(y_pred)
# y_pred_unscaled

# %%
# y_test_unscaled_untransformed = np.exp(y_test_unscaled)
# y_test_unscaled_untransformed

# %%
# y_pred_unscaled_untransformed = np.exp(y_pred_unscaled)
# y_pred_unscaled_untransformed

# %% [markdown]
# # Log transformation - Price

# %%
df['price_transformed'] = np.log(df['price'])

# %% [markdown]
# # Encoding

# %%
df = df.reset_index()
df
# Out:
#         level_0   index Report_Run_Time  carrier    Trip_Type Airport_Route  \
# 0             0       0      2024-03-10   Spirit  Rounds Trip     EWR - LAX
# 1             1       1      2024-03-10   Alaska  Rounds Trip     EWR - LAX
# 2             2       2      2024-03-10  JetBlue  Rounds Trip     EWR - LAX
# 3             3       3      2024-03-10   United  Rounds Trip     EWR - LAX
# 4             4       4      2024-03-10   Spirit  Rounds Trip     LGA - LAX
# ...         ...     ...             ...      ...          ...           ...
# 135147   135209  135242      2024-04-06   Alaska      One Way     LAX - EWR
# 135148   135210  135243      2024-04-06  JetBlue      One Way     LAX - EWR
# 135149   135211  135244      2024-04-06    Delta      One Way     LAX - JFK
# 135150   135212  135245      2024-04-06    Delta      One Way     LAX - JFK
# 135151   135213  135246      2024-04-06    Delta      One Way     LAX - JFK
#
#         price                           overhead_bin  layover_count  \
# 0       211.0     Additional charge for overhead bin            0.0
# 1       297.0  No additional charge for overhead bin            0.0
# 2       298.0     Additional charge for overhead bin            0.0
# 3       302.0     Additional charge for overhead bin            0.0
# 4       269.0  No additional charge for overhead bin            1.0
# ...       ...                                    ...            ...
# 135147  259.0  No additional charge for overhead bin            0.0
# 135148  259.0     Additional charge for overhead bin            0.0
# 135149  274.0  No additional charge for overhead bin            0.0
# 135150  274.0  No additional charge for overhead bin            0.0
# 135151  274.0  No additional charge for overhead bin            0.0
#
#         round_trip_duration  ...  carbon_emission% num  Days_to_Fly  \
# 0                        89  ...                    82           18
# 1                        89  ...                    76           18
# 2                        89  ...                   118           18
# 3                        89  ...                   119           18
# 4                        89  ...                    94           18
# ...                     ...  ...                   ...          ...
# 135147                    0  ...                    85           89
# 135148                    0  ...                   100           89
# 135149                    0  ...                    85           89
# 135150                    0  ...                    85           89
# 135151                    0  ...                    85           89
#
#           from_timestamp_1      to_timestamp_1 from_hour_segment  \
# 0      2024-03-28 06:47:00 2024-03-28 10:15:00    3. 6 AM - 9 AM
# 1      2024-03-28 07:30:00 2024-03-28 10:48:00    3. 6 AM - 9 AM
# 2      2024-03-28 05:15:00 2024-03-28 08:30:00    2. 3 AM - 6 AM
# 3      2024-03-28 12:00:00 2024-03-28 15:24:00   5. 12 PM - 3 PM
# 4      2024-03-28 16:29:00 2024-03-28 17:00:00    6. 3 PM - 6 PM
# ...                    ...                 ...               ...
# 135147 2024-07-04 10:20:00 2024-07-05 18:59:00   4. 9 AM - 12 PM
# 135148 2024-07-04 11:20:00 2024-07-05 19:49:00   4. 9 AM - 12 PM
# 135149 2024-07-04 06:00:00 2024-07-05 14:35:00    3. 6 AM - 9 AM
# 135150 2024-07-04 09:20:00 2024-07-05 18:15:00   4. 9 AM - 12 PM
# 135151 2024-07-04 16:00:00 2024-07-05 00:37:00    6. 3 PM - 6 PM
#
#         to_hour_segment flight_duration_value      Holiday Fly_WeekDay  \
# 0       4. 9 AM - 12 PM                   6.5  Not_Holiday           4
# 1       4. 9 AM - 12 PM                   6.3  Not_Holiday           4
# 2        3. 6 AM - 9 AM                   6.2  Not_Holiday           4
# 3        6. 3 PM - 6 PM                   6.4  Not_Holiday           4
# 4        6. 3 PM - 6 PM                  27.5  Not_Holiday           4
# ...                 ...                   ...          ...         ...
# 135147   7. 6 PM - 9 PM                   5.6      Holiday           4
# 135148   7. 6 PM - 9 PM                   5.5      Holiday           4
# 135149  5. 12 PM - 3 PM                   5.6      Holiday           4
# 135150   7. 6 PM - 9 PM                   5.9      Holiday           4
# 135151  1. 12 AM - 3 AM                   5.6      Holiday           4
#
#         price_transformed
# 0                5.351858
# 1                5.693732
# 2                5.697093
# 3                5.710427
# 4                5.594711
# ...                   ...
# 135147           5.556828
# 135148           5.556828
# 135149           5.613128
# 135150           5.613128
# 135151           5.613128
#
# [135152 rows x 21 columns]

# %% [markdown]
# ## One Hot Encoding

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'Report_Run_Time', 'carrier', 'Trip_Type',
#        'Airport_Route', 'price', 'overhead_bin', 'layover_count',
#        'round_trip_duration', 'Carbon emissions estimate num',
#        'carbon_emission% num', 'Days_to_Fly', 'from_timestamp_1',
#        'to_timestamp_1', 'from_hour_segment', 'to_hour_segment',
#        'flight_duration_value', 'Holiday', 'Fly_WeekDay', 'price_transformed'],
#       dtype='object')

# %%
df = df[['Report_Run_Time', 'carrier', 'Trip_Type',
       'Airport_Route', 'price', 'overhead_bin', 'layover_count',
       'round_trip_duration', 'Carbon emissions estimate num',
       'carbon_emission% num', 'Days_to_Fly', 'from_timestamp_1',
       'to_timestamp_1', 'from_hour_segment', 'to_hour_segment',
       'flight_duration_value', 'Holiday', 'Fly_WeekDay', 'price_transformed']]

# %%
# # columns to encode 
# categorical_columns = ['carrier', 'Trip_Type', 'Airport_Route','overhead_bin', 'from_hour_segment', 'to_hour_segment','Holiday', 'Fly_WeekDay']

# %%
# from sklearn.preprocessing import OneHotEncoder

# # encoder = OneHotEncoder(sparse_output=False, drop='first')
# encoder = OneHotEncoder(sparse_output=False)
# one_hot_encoded = encoder.fit_transform(df[categorical_columns])
# one_hot_df = pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(categorical_columns))

# %%
# df.shape

# %%
# one_hot_df.shape

# %%
# one_hot_df.head()

# %%
# df_encoded = pd.concat([df, one_hot_df], axis=1)
# df_encoded = df_encoded.drop(categorical_columns, axis=1)

# %%
# df_encoded = df_encoded.drop(['Report_Run_Time','from_timestamp_1','to_timestamp_1','price'], axis=1)
# df_encoded.head(2)

# %%
# df_encoded.isnull().sum()

# %%
columns_to_encode = ['carrier','Trip_Type','Airport_Route','overhead_bin','from_hour_segment','to_hour_segment', 'Holiday' ]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for columns in columns_to_encode:
    df[columns] = label_encoder.fit_transform(df[columns])

df
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
# C:\Users\anshu\AppData\Local\Temp\ipykernel_61508\1666453587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = label_encoder.fit_transform(df[columns])
#        Report_Run_Time  carrier  Trip_Type  Airport_Route  price  \
# 0           2024-03-10        5          1              0  211.0
# 1           2024-03-10        0          1              0  297.0
# 2           2024-03-10        4          1              0  298.0
# 3           2024-03-10        8          1              0  302.0
# 4           2024-03-10        5          1              5  269.0
# ...                ...      ...        ...            ...    ...
# 135147      2024-04-06        0          0              2  259.0
# 135148      2024-04-06        4          0              2  259.0
# 135149      2024-04-06        2          0              3  274.0
# 135150      2024-04-06        2          0              3  274.0
# 135151      2024-04-06        2          0              3  274.0
#
#         overhead_bin  layover_count  round_trip_duration  \
# 0                  0            0.0                   89
# 1                  1            0.0                   89
# 2                  0            0.0                   89
# 3                  0            0.0                   89
# 4                  1            1.0                   89
# ...              ...            ...                  ...
# 135147             1            0.0                    0
# 135148             0            0.0                    0
# 135149             1            0.0                    0
# 135150             1            0.0                    0
# 135151             1            0.0                    0
#
#         Carbon emissions estimate num  carbon_emission% num  Days_to_Fly  \
# 0                                 293                    82           18
# 1                                 272                    76           18
# 2                                 422                   118           18
# 3                                 427                   119           18
# 4                                 338                    94           18
# ...                               ...                   ...          ...
# 135147                            300                    85           89
# 135148                            370                   100           89
# 135149                            298                    85           89
# 135150                            298                    85           89
# 135151                            298                    85           89
#
#           from_timestamp_1      to_timestamp_1  from_hour_segment  \
# 0      2024-03-28 06:47:00 2024-03-28 10:15:00                  2
# 1      2024-03-28 07:30:00 2024-03-28 10:48:00                  2
# 2      2024-03-28 05:15:00 2024-03-28 08:30:00                  1
# 3      2024-03-28 12:00:00 2024-03-28 15:24:00                  4
# 4      2024-03-28 16:29:00 2024-03-28 17:00:00                  5
# ...                    ...                 ...                ...
# 135147 2024-07-04 10:20:00 2024-07-05 18:59:00                  3
# 135148 2024-07-04 11:20:00 2024-07-05 19:49:00                  3
# 135149 2024-07-04 06:00:00 2024-07-05 14:35:00                  2
# 135150 2024-07-04 09:20:00 2024-07-05 18:15:00                  3
# 135151 2024-07-04 16:00:00 2024-07-05 00:37:00                  5
#
#         to_hour_segment  flight_duration_value  Holiday  Fly_WeekDay  \
# 0                     3                    6.5        1            4
# 1                     3                    6.3        1            4
# 2                     2                    6.2        1            4
# 3                     5                    6.4        1            4
# 4                     5                   27.5        1            4
# ...                 ...                    ...      ...          ...
# 135147                6                    5.6        0            4
# 135148                6                    5.5        0            4
# 135149                4                    5.6        0            4
# 135150                6                    5.9        0            4
# 135151                0                    5.6        0            4
#
#         price_transformed
# 0                5.351858
# 1                5.693732
# 2                5.697093
# 3                5.710427
# 4                5.594711
# ...                   ...
# 135147           5.556828
# 135148           5.556828
# 135149           5.613128
# 135150           5.613128
# 135151           5.613128
#
# [135152 rows x 19 columns]

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler
x_scaler = StandardScaler()
y_scaler = StandardScaler()

# %%
x_train_scaled = x_scaler.fit_transform(df[['layover_count', 'round_trip_duration',
       'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly','flight_duration_value']])
y_train_scaled = y_scaler.fit_transform(df[['price_transformed']])

# %%
df_encoded = df.drop(columns=['layover_count', 'round_trip_duration',
       'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly',
       'flight_duration_value', 'price_transformed'])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=['layover_count', 'round_trip_duration',
       'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly','flight_duration_value'])

# %%
df_encoded = pd.concat([x_train_scaled, df_encoded], axis=1)
df_encoded.columns
# Out:
# Index(['layover_count', 'round_trip_duration', 'Carbon emissions estimate num',
#        'carbon_emission% num', 'Days_to_Fly', 'flight_duration_value',
#        'Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route', 'price',
#        'overhead_bin', 'from_timestamp_1', 'to_timestamp_1',
#        'from_hour_segment', 'to_hour_segment', 'Holiday', 'Fly_WeekDay'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Report_Run_Time', 'carrier', 'Trip_Type', 'Airport_Route', 'price',
#        'overhead_bin', 'layover_count', 'round_trip_duration',
#        'Carbon emissions estimate num', 'carbon_emission% num', 'Days_to_Fly',
#        'from_timestamp_1', 'to_timestamp_1', 'from_hour_segment',
#        'to_hour_segment', 'flight_duration_value', 'Holiday', 'Fly_WeekDay',
#        'price_transformed'],
#       dtype='object')

# %%
X = df_encoded[['layover_count', 'round_trip_duration', 'Carbon emissions estimate num',
       'Days_to_Fly', 'flight_duration_value', 'carrier', 'Trip_Type', 'Airport_Route',
       'overhead_bin','from_hour_segment', 'to_hour_segment', 'Holiday', 'Fly_WeekDay']]

# %%
Y = pd.DataFrame(y_train_scaled, columns=['price_transformed'])

# %%
df_encoded.head()
# Out:
#    layover_count  round_trip_duration  Carbon emissions estimate num  \
# 0      -0.375820             2.152057                      -0.229896
# 1      -0.375820             2.152057                      -0.273949
# 2      -0.375820             2.152057                       0.040716
# 3      -0.375820             2.152057                       0.051205
# 4       2.117448             2.152057                      -0.135497
#
#    carbon_emission% num  Days_to_Fly  flight_duration_value Report_Run_Time  \
# 0             -0.232006    -1.070311              -0.021069      2024-03-10
# 1             -0.276908    -1.070311              -0.093390      2024-03-10
# 2              0.037405    -1.070311              -0.129551      2024-03-10
# 3              0.044888    -1.070311              -0.057230      2024-03-10
# 4             -0.142203    -1.070311               7.572639      2024-03-10
#
#    carrier  Trip_Type  Airport_Route  price  overhead_bin    from_timestamp_1  \
# 0        5          1              0  211.0             0 2024-03-28 06:47:00
# 1        0          1              0  297.0             1 2024-03-28 07:30:00
# 2        4          1              0  298.0             0 2024-03-28 05:15:00
# 3        8          1              0  302.0             0 2024-03-28 12:00:00
# 4        5          1              5  269.0             1 2024-03-28 16:29:00
#
#        to_timestamp_1  from_hour_segment  to_hour_segment  Holiday  \
# 0 2024-03-28 10:15:00                  2                3        1
# 1 2024-03-28 10:48:00                  2                3        1
# 2 2024-03-28 08:30:00                  1                2        1
# 3 2024-03-28 15:24:00                  4                5        1
# 4 2024-03-28 17:00:00                  5                5        1
#
#    Fly_WeekDay
# 0            4
# 1            4
# 2            4
# 3            4
# 4            4

# %% [markdown]
# # Feature Selection

# %%
Y.shape
# Out:
# (135152, 1)

# %%
df_encoded = pd.concat([df_encoded[['layover_count', 'round_trip_duration', 'Carbon emissions estimate num',
       'Days_to_Fly', 'flight_duration_value', 'carrier', 'Trip_Type', 'Airport_Route',
       'overhead_bin','from_hour_segment', 'to_hour_segment', 'Holiday', 'Fly_WeekDay']], Y], axis=1)
df_encoded
# Out:
#         layover_count  round_trip_duration  Carbon emissions estimate num  \
# 0           -0.375820             2.152057                      -0.229896
# 1           -0.375820             2.152057                      -0.273949
# 2           -0.375820             2.152057                       0.040716
# 3           -0.375820             2.152057                       0.051205
# 4            2.117448             2.152057                      -0.135497
# ...               ...                  ...                            ...
# 135147      -0.375820            -0.838161                      -0.215212
# 135148      -0.375820            -0.838161                      -0.068368
# 135149      -0.375820            -0.838161                      -0.219407
# 135150      -0.375820            -0.838161                      -0.219407
# 135151      -0.375820            -0.838161                      -0.219407
#
#         Days_to_Fly  flight_duration_value  carrier  Trip_Type  Airport_Route  \
# 0         -1.070311              -0.021069        5          1              0
# 1         -1.070311              -0.093390        0          1              0
# 2         -1.070311              -0.129551        4          1              0
# 3         -1.070311              -0.057230        8          1              0
# 4         -1.070311               7.572639        5          1              5
# ...             ...                    ...      ...        ...            ...
# 135147     1.700743              -0.346514        0          0              2
# 135148     1.700743              -0.382674        4          0              2
# 135149     1.700743              -0.346514        2          0              3
# 135150     1.700743              -0.238032        2          0              3
# 135151     1.700743              -0.346514        2          0              3
#
#         overhead_bin  from_hour_segment  to_hour_segment  Holiday  \
# 0                  0                  2                3        1
# 1                  1                  2                3        1
# 2                  0                  1                2        1
# 3                  0                  4                5        1
# 4                  1                  5                5        1
# ...              ...                ...              ...      ...
# 135147             1                  3                6        0
# 135148             0                  3                6        0
# 135149             1                  2                4        0
# 135150             1                  3                6        0
# 135151             1                  5                0        0
#
#         Fly_WeekDay  price_transformed
# 0                 4          -0.848991
# 1                 4          -0.138306
# 2                 4          -0.131319
# 3                 4          -0.103601
# 4                 4          -0.344150
# ...             ...                ...
# 135147            4          -0.422901
# 135148            4          -0.422901
# 135149            4          -0.305865
# 135150            4          -0.305865
# 135151            4          -0.305865
#
# [135152 rows x 14 columns]

# %% [markdown]
# ## Technique 1 - Correlation Analysis

# %%
sns.heatmap(df_encoded.corr())
fi_df1 = df_encoded.corr()['price_transformed'].iloc[:-1].to_frame().reset_index().rename(columns={'index':'feature','price':'corr_coeff'})
fi_df1 = fi_df1.sort_values('price_transformed', ascending=False)
fi_df1

# %% [markdown]
# ## Technique 2 - Random Forest Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

# Train a Random Forest regressor on label encoded data
rf_label = RandomForestRegressor(n_estimators=100, random_state=42)
rf_label.fit(X, Y)

# Extract feature importance scores for label encoded data
fi_df2 = pd.DataFrame({
    'feature': X.columns,
    'rf_importance': rf_label.feature_importances_
}).sort_values(by='rf_importance', ascending=False)

fi_df2

# %% [markdown]
# ## Technique 3 - Gradient Boosting Feature Importance

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Train a Random Forest regressor on label encoded data
gb_label = GradientBoostingRegressor()
gb_label.fit(X, Y)

# Extract feature importance scores for label encoded data
fi_df3 = pd.DataFrame({
    'feature': X.columns,
    'gb_importance': gb_label.feature_importances_
}).sort_values(by='gb_importance', ascending=False)

fi_df3

# %% [markdown]
# ## Technique 4 - Permutation Importance

# %%
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split

X_train_label, X_test_label, y_train_label, y_test_label = train_test_split(X, Y, test_size=0.2, random_state=42)

# Train a Random Forest regressor on label encoded data
rf_label = RandomForestRegressor(n_estimators=100, random_state=42)
rf_label.fit(X_train_label, y_train_label)

# Calculate Permutation Importance
perm_importance = permutation_importance(rf_label, X_test_label, y_test_label, n_repeats=15, random_state=42)

# Organize results into a DataFrame
fi_df4 = pd.DataFrame({
    'feature': X.columns,
    'permutation_importance': perm_importance.importances_mean
}).sort_values(by='permutation_importance', ascending=False)

fi_df4

# %% [markdown]
# ## Technique 5 - LASSO

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# Standardize the features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# Train a LASSO regression model
# We'll use a relatively small value for alpha (the regularization strength) for demonstration purposes
lasso = Lasso(alpha=0.01, random_state=42)
lasso.fit(X, Y)

# Extract coefficients
fi_df5 = pd.DataFrame({
    'feature': X.columns,
    'lasso_coeff': lasso.coef_
}).sort_values(by='lasso_coeff', ascending=False)

fi_df5

# %% [markdown]
# ## Technique 6 - RFE

# %%
# from sklearn.feature_selection import RFE

# # Initialize the base estimator
# estimator = RandomForestRegressor()

# # Apply RFE on the label-encoded and standardized training data
# selector_label = RFE(estimator, n_features_to_select=X.shape[1], step=1)
# selector_label = selector_label.fit(X, Y)

# # Get the selected features based on RFE
# selected_features = X.columns[selector_label.support_]

# # Extract the coefficients for the selected features from the underlying linear regression model
# selected_coefficients = selector_label.estimator_.feature_importances_

# # Organize the results into a DataFrame
# fi_df6 = pd.DataFrame({
#     'feature': selected_features,
#     'rfe_score': selected_coefficients
# }).sort_values(by='rfe_score', ascending=False)

# fi_df6

# %% [markdown]
# ## Technique 7 - Linear Regression Weights

# %%
# # Train a linear regression model on the label-encoded and standardized training data
# lin_reg = LinearRegression()
# lin_reg.fit(X, Y)

# # Extract coefficients
# fi_df7 = pd.DataFrame({
#     'feature': X.columns,
#     'reg_coeffs': lin_reg.coef_[0]
# }).sort_values(by='reg_coeffs', ascending=False)

# fi_df7

# %% [markdown]
# ## Technique 8 - SHAP

# %%
# import shap

# # Compute SHAP values using the trained Random Forest model
# rf = RandomForestRegressor(n_estimators=100, random_state=42)
# rf.fit(X, Y)

# explainer = shap.TreeExplainer(rf)
# shap_values = explainer.shap_values(X)

# # Summing the absolute SHAP values across all samples to get an overall measure of feature importance
# shap_sum = np.abs(shap_values).mean(axis=0)

# shap_values

# %%
# fi_df8 = pd.DataFrame({
#     'feature': X.columns,
#     'SHAP_score': np.abs(shap_values).mean(axis=0)
# }).sort_values(by='SHAP_score', ascending=False)

# fi_df8

# %%
# final_fi_df = fi_df1.merge(fi_df2,on='feature').merge(fi_df3,on='feature').merge(fi_df4,on='feature').merge(fi_df5,on='feature').merge(fi_df6,on='feature').merge(fi_df7,on='feature').set_index('feature')
# final_fi_df

# %%
# # normalize the score
# final_fi_df = final_fi_df.divide(final_fi_df.sum(axis=0), axis=1)

# %%
# final_fi_df

# %%
# # final_fi_df[['rf_importance','gb_importance','permutation_importance','rfe_score','SHAP_score']].mean(axis=1).sort_values(ascending=False)
# final_fi_df[['rf_importance','gb_importance','permutation_importance','rfe_score']].mean(axis=1).sort_values(ascending=False)

# %%
# from sklearn.model_selection import KFold, cross_val_score
# kfold = KFold(n_splits=10, shuffle=True, random_state=42)
# scores = cross_val_score(Random_Forest_regressor, X, Y, cv=kfold, scoring='r2')
# scores

# %% [markdown]
# # Model Selection

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#   Report_Run_Time  carrier  Trip_Type  Airport_Route  price  overhead_bin  \
# 0      2024-03-10        5          1              0  211.0             0
# 1      2024-03-10        0          1              0  297.0             1
# 2      2024-03-10        4          1              0  298.0             0
# 3      2024-03-10        8          1              0  302.0             0
# 4      2024-03-10        5          1              5  269.0             1
#
#    layover_count  round_trip_duration  Carbon emissions estimate num  \
# 0            0.0                   89                            293
# 1            0.0                   89                            272
# 2            0.0                   89                            422
# 3            0.0                   89                            427
# 4            1.0                   89                            338
#
#    carbon_emission% num  Days_to_Fly    from_timestamp_1      to_timestamp_1  \
# 0                    82           18 2024-03-28 06:47:00 2024-03-28 10:15:00
# 1                    76           18 2024-03-28 07:30:00 2024-03-28 10:48:00
# 2                   118           18 2024-03-28 05:15:00 2024-03-28 08:30:00
# 3                   119           18 2024-03-28 12:00:00 2024-03-28 15:24:00
# 4                    94           18 2024-03-28 16:29:00 2024-03-28 17:00:00
#
#    from_hour_segment  to_hour_segment  flight_duration_value  Holiday  \
# 0                  2                3                    6.5        1
# 1                  2                3                    6.3        1
# 2                  1                2                    6.2        1
# 3                  4                5                    6.4        1
# 4                  5                5                   27.5        1
#
#    Fly_WeekDay  price_transformed
# 0            4           5.351858
# 1            4           5.693732
# 2            4           5.697093
# 3            4           5.710427
# 4            4           5.594711

# %%
columns_to_encode = ['carrier','Trip_Type','Airport_Route','overhead_bin','from_hour_segment','to_hour_segment', 'Holiday' ]

# %%
from sklearn.compose import ColumnTransformer
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['round_trip_duration', 'Carbon emissions estimate num', 'Days_to_Fly', 'flight_duration_value']),
        # ('cat', OrdinalEncoder(), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
from sklearn.pipeline import Pipeline
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
from sklearn.model_selection import KFold, cross_val_score
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, Y, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.6071227417704761, 0.0060409519352861854)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['round_trip_duration',
#                                                    'Carbon emissions estimate '
#                                                    'num',
#                                                    'Days_to_Fly',
#                                                    'flight_duration_value'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.7266731465271431

# %%
def scorer(model_name, model):    
    output = []
    output.append(model_name)
    pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', model)
    ])
    # K-fold cross-validation
    kfold = KFold(n_splits=2, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, Y, cv=kfold, scoring='r2')
    output.append(scores.mean())
    X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
    pipeline.fit(X_train,y_train)
    y_pred = pipeline.predict(X_test)
    y_pred = np.expm1(y_pred)
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    return output

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from xgboost import XGBRegressor

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    # 'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    print(model_name)
    model_output.append(scorer(model_name, model))
# Out:
# linear_reg
# ridge
# LASSO
# decision tree
# random forest
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# extra trees
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# gradient boosting
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# adaboost
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# mlp
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1625: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1625: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1625: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# xgboost

# %%
model_output
# Out:
# [['linear_reg', 0.607112979041712, 0.7266731465271431],
#  ['ridge', 0.60711294272491, 0.7266742219120629],
#  ['LASSO', -2.0694115698827176e-07, 1.0594060612329974],
#  ['decision tree', 0.8135231700917729, 0.4058488648833139],
#  ['random forest', 0.8928209975189061, 0.34267911284186536],
#  ['extra trees', 0.8840445117087183, 0.3427261190145828],
#  ['gradient boosting', 0.8230216602632765, 0.5133132030231239],
#  ['adaboost', 0.6935033931531851, 0.6932798113434002],
#  ['mlp', 0.8251452716883454, 0.5044614160437648],
#  ['xgboost', 0.8880373619129718, 0.40105918776835103]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                 name            r2       mae
# 4      random forest  8.928210e-01  0.342679
# 5        extra trees  8.840445e-01  0.342726
# 9            xgboost  8.880374e-01  0.401059
# 3      decision tree  8.135232e-01  0.405849
# 8                mlp  8.251453e-01  0.504461
# 6  gradient boosting  8.230217e-01  0.513313
# 7           adaboost  6.935034e-01  0.693280
# 0         linear_reg  6.071130e-01  0.726673
# 1              ridge  6.071129e-01  0.726674
# 2              LASSO -2.069412e-07  1.059406

# %% [markdown]
# ## OneHotEncoding

# %%
columns_to_encode = ['carrier','Trip_Type','Airport_Route','overhead_bin','from_hour_segment','to_hour_segment', 'Holiday' ]

# %%
df.head()
# Out:
#   Report_Run_Time  carrier  Trip_Type  Airport_Route  price  overhead_bin  \
# 0      2024-03-10        5          1              0  211.0             0
# 1      2024-03-10        0          1              0  297.0             1
# 2      2024-03-10        4          1              0  298.0             0
# 3      2024-03-10        8          1              0  302.0             0
# 4      2024-03-10        5          1              5  269.0             1
#
#    layover_count  round_trip_duration  Carbon emissions estimate num  \
# 0            0.0                   89                            293
# 1            0.0                   89                            272
# 2            0.0                   89                            422
# 3            0.0                   89                            427
# 4            1.0                   89                            338
#
#    carbon_emission% num  Days_to_Fly    from_timestamp_1      to_timestamp_1  \
# 0                    82           18 2024-03-28 06:47:00 2024-03-28 10:15:00
# 1                    76           18 2024-03-28 07:30:00 2024-03-28 10:48:00
# 2                   118           18 2024-03-28 05:15:00 2024-03-28 08:30:00
# 3                   119           18 2024-03-28 12:00:00 2024-03-28 15:24:00
# 4                    94           18 2024-03-28 16:29:00 2024-03-28 17:00:00
#
#    from_hour_segment  to_hour_segment  flight_duration_value  Holiday  \
# 0                  2                3                    6.5        1
# 1                  2                3                    6.3        1
# 2                  1                2                    6.2        1
# 3                  4                5                    6.4        1
# 4                  5                5                   27.5        1
#
#    Fly_WeekDay  price_transformed
# 0            4           5.351858
# 1            4           5.693732
# 2            4           5.697093
# 3            4           5.710427
# 4            4           5.594711

# %%
from sklearn.preprocessing import OneHotEncoder
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['round_trip_duration', 'Carbon emissions estimate num', 'Days_to_Fly', 'flight_duration_value']),
        # ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first'),columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=2, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, Y, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.6533588042625195, 0.0007562922609535283)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['round_trip_duration',
#                                                    'Carbon emissions estimate '
#                                                    'num',
#                                                    'Days_to_Fly',
#                                                    'flight_duration_value']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['carrier', 'Trip_Type',
#                                                    'Airport_Route',
#                                                    'overhead_bin',
#                                                    'from_hour_segment',
#                                                    'to_hour_segment',
#                                                    'Holiday'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6994390488083218

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=2, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, Y, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    # 'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    print(model_name)
    model_output.append(scorer(model_name, model))
# Out:
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1625: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1625: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1625: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                 name            r2       mae
# 4      random forest  8.919960e-01  0.347281
# 5        extra trees  8.791266e-01  0.353090
# 9            xgboost  8.855800e-01  0.404234
# 3      decision tree  8.109829e-01  0.431484
# 8                mlp  8.413550e-01  0.480742
# 6  gradient boosting  8.215143e-01  0.516206
# 7           adaboost  6.835996e-01  0.697648
# 0         linear_reg  6.533588e-01  0.699439
# 1              ridge  6.533585e-01  0.699467
# 2              LASSO -2.069412e-07  1.059406

# %% [markdown]
# ## OneHotEncoding With PCA

# %%
# # Creating a column transformer for preprocessing
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
#         ('cat', OrdinalEncoder(), columns_to_encode),
#         ('cat1',OneHotEncoder(drop='first',sparse_output=False),['sector','agePossession'])
#     ], 
#     remainder='passthrough'
# )

# %%
# # Creating a pipeline
# pipeline = Pipeline([
#     ('preprocessor', preprocessor),
#     ('pca', PCA(n_components=0.95)),
#     ('regressor', LinearRegression())
# ])

# %%
# # K-fold cross-validation
# kfold = KFold(n_splits=10, shuffle=True, random_state=42)
# scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
# scores.mean()

# %%
# scores.std()

# %%
# def scorer(model_name, model):
    
#     output = []
    
#     output.append(model_name)
    
#     pipeline = Pipeline([
#         ('preprocessor', preprocessor),
#         ('pca', PCA(n_components=0.95)),
#         ('regressor', model)
#     ])
    
#     # K-fold cross-validation
#     kfold = KFold(n_splits=10, shuffle=True, random_state=42)
#     scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
#     output.append(scores.mean())
    
#     X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
#     pipeline.fit(X_train,y_train)
    
#     y_pred = pipeline.predict(X_test)
    
#     y_pred = np.expm1(y_pred)
    
#     output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
#     return output

# %%
# model_dict = {
#     'linear_reg':LinearRegression(),
#     'svr':SVR(),
#     'ridge':Ridge(),
#     'LASSO':Lasso(),
#     'decision tree': DecisionTreeRegressor(),
#     'random forest':RandomForestRegressor(),
#     'extra trees': ExtraTreesRegressor(),
#     'gradient boosting': GradientBoostingRegressor(),
#     'adaboost': AdaBoostRegressor(),
#     'mlp': MLPRegressor(),
#     'xgboost':XGBRegressor()
# }

# %%
# model_output = []
# for model_name,model in model_dict.items():
#     model_output.append(scorer(model_name, model))

# %%
# model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
# model_df.sort_values(['mae'])

# %% [markdown]
# ## Taget Encode

# %%
# import category_encoders as ce

# columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# # Creating a column transformer for preprocessing
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
#         ('cat', OrdinalEncoder(), columns_to_encode),
#         ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
#         ('target_enc', ce.TargetEncoder(), ['sector'])
#     ], 
#     remainder='passthrough'
)

# %%
# !pip install category_encoders

# %%
# # Creating a pipeline
# pipeline = Pipeline([
#     ('preprocessor', preprocessor),
#     ('regressor', LinearRegression())
# ])

# %%
# # K-fold cross-validation
# kfold = KFold(n_splits=10, shuffle=True, random_state=42)
# scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
# scores.mean(),scores.std()

# %%
# def scorer(model_name, model):
    
#     output = []
    
#     output.append(model_name)
    
#     pipeline = Pipeline([
#         ('preprocessor', preprocessor),
#         ('regressor', model)
#     ])
    
#     # K-fold cross-validation
#     kfold = KFold(n_splits=10, shuffle=True, random_state=42)
#     scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
#     output.append(scores.mean())
    
#     X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
#     pipeline.fit(X_train,y_train)
    
#     y_pred = pipeline.predict(X_test)
    
#     y_pred = np.expm1(y_pred)
    
#     output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
#     return output

# %%
# model_dict = {
#     'linear_reg':LinearRegression(),
#     'svr':SVR(),
#     'ridge':Ridge(),
#     'LASSO':Lasso(),
#     'decision tree': DecisionTreeRegressor(),
#     'random forest':RandomForestRegressor(),
#     'extra trees': ExtraTreesRegressor(),
#     'gradient boosting': GradientBoostingRegressor(),
#     'adaboost': AdaBoostRegressor(),
#     'mlp': MLPRegressor(),
#     'xgboost':XGBRegressor()
# }

# %%
# model_output = []
# for model_name,model in model_dict.items():
#     model_output.append(scorer(model_name, model))

# %%
# model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
# model_df.sort_values(['mae'])

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'regressor__n_estimators': [100, 300],
    'regressor__max_depth': [None, 30],
    'regressor__max_samples':[0.1, 0.5, 1.0],
    'regressor__max_features': ['log2', 'sqrt', None]
}

# %%
from sklearn.preprocessing import OneHotEncoder
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['round_trip_duration', 'Carbon emissions estimate num', 'Days_to_Fly', 'flight_duration_value']),
        # ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first'),columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, Y)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['round_trip_duration',
#                                                                           'Carbon '
#                                                                           'emissions '
#                                                                           'estimate '
#                                                                           'num',
#                                                                           'Days_to_Fly',
#                                                                           'flight_duration_value']),
#                                                                         ('cat1',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['carrier',
#                                                                           'Trip_Type',
#                                                                           'Airport_Route',
#                                                                           'overhead_bin',
#                                                                           'from_hour_segment',
#                                                                           'to_hour_segment',
#                                                                           'Holiday'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 30],
#                          'regressor__max_features': ['log2', 'sqrt', None],
#                          'regressor__max_samples': [0.1, 0.5, 1.0],
#                          'regressor__n_estimators': [100, 300]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': None,
#  'regressor__max_features': None,
#  'regressor__max_samples': 1.0,
#  'regressor__n_estimators': 300}

# %%
search.best_score_
# Out:
# 0.9032375858900679

# %%
final_pipe.fit(X,Y)
# Out:
# c:\Users\anshu\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['round_trip_duration',
#                                                    'Carbon emissions estimate '
#                                                    'num',
#                                                    'Days_to_Fly',
#                                                    'flight_duration_value']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['carrier', 'Trip_Type',
#                                                    'Airport_Route',
#                                                    'overhead_bin',
#                                                    'from_hour_segment',
#                                                    'to_hour_segment',
#                                                    'Holiday'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_features=None, max_samples=1.0,
#                                        n_estimators=300))])

# %%
X.head()
# Out:
#    layover_count  round_trip_duration  Carbon emissions estimate num  \
# 0      -0.380976             2.163195                      -0.234492
# 1      -0.380976             2.163195                      -0.279774
# 2      -0.380976             2.163195                       0.043669
# 3      -0.380976             2.163195                       0.054450
# 4       2.169918             2.163195                      -0.137459
#
#    Days_to_Fly  flight_duration_value  carrier  Trip_Type  Airport_Route  \
# 0    -1.054764              -0.018635        5          1              0
# 1    -1.054764              -0.091811        0          1              0
# 2    -1.054764              -0.128399        4          1              0
# 3    -1.054764              -0.055223        8          1              0
# 4    -1.054764               7.664839        5          1              5
#
#    overhead_bin  from_hour_segment  to_hour_segment  Holiday  Fly_WeekDay
# 0             0                  2                3        1            4
# 1             1                  2                3        1            4
# 2             0                  1                2        1            4
# 3             0                  4                5        1            4
# 4             1                  5                5        1            4

# %%
y_pred = final_pipe.predict(X_test)

# %% [markdown]
# # Analytics Moule

# %% [markdown]
# Price Prediction Modeule
